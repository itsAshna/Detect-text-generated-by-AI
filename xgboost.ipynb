# %%
import pandas as pd


file_path = '/Users/ashnaarora/Downloads/Dataset_with_new_features (1).csv'
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (9611, 29)

# %%
df.columns
# Out:
# Index(['essay_id', 'text', 'source', 'generated', 'temp', 'word_count',
#        'average_word_length', 'vocabulary_richness', 'flesch_kincaid',
#        'gunning_fog', 'smog_index', 'polarity', 'subjectivity',
#        'misspelled_word_count', 'sentence_length', 'punctuation_count',
#        'punctuation_density', 'pos_counts', 'pos_density', 'noun_count',
#        'verb_count', 'adjective_count', 'adverb_count', 'noun_density',
#        'verb_density', 'adjective_density', 'adverb_density', 'perplexity',
#        'ai_ratio'],
#       dtype='object')

# %%
df['misspelling_rate'] = df['misspelled_word_count'] / df['word_count']
df = df.drop(columns=['misspelled_word_count'])

# %%
df.shape
# Out:
# (9611, 29)

# %%
import pandas as pd

print("Number of NaN values in each column:")
print(df.isna().sum())


df.fillna(0.0, inplace=True)

print("\nAfter replacing NaN values:")
print(df.isna().sum())
# Out:
# Number of NaN values in each column:
# essay_id                 0
# text                     0
# source                 912
# generated                0
# temp                     1
# word_count               0
# average_word_length      0
# vocabulary_richness      0
# flesch_kincaid           0
# gunning_fog              0
# smog_index               0
# polarity                 0
# subjectivity             0
# sentence_length          0
# punctuation_count        0
# punctuation_density      0
# pos_counts               0
# pos_density              0
# noun_count               0
# verb_count               0
# adjective_count          0
# adverb_count             0
# noun_density             0
# verb_density             0
# adjective_density        0
# adverb_density           0
# perplexity               1
# ai_ratio                 0
# misspelling_rate         0
# dtype: int64
#
# After replacing NaN values:
# essay_id               0
# text                   0
# source                 0
# generated              0
# temp                   0
# word_count             0
# average_word_length    0
# vocabulary_richness    0
# flesch_kincaid         0
# gunning_fog            0
# smog_index             0
# polarity               0
# subjectivity           0
# sentence_length        0
# punctuation_count      0
# punctuation_density    0
# pos_counts             0
# pos_density            0
# noun_count             0
# verb_count             0
# adjective_count        0
# adverb_count           0
# noun_density           0
# verb_density           0
# adjective_density      0
# adverb_density         0
# perplexity             0
# ai_ratio               0
# misspelling_rate       0
# dtype: int64

# %%
import string

columns_to_drop = [
    'word_count', 'average_word_length', 'sentence_length',
    'noun_count', 'verb_count', 'adjective_count', 'adverb_count', 'flesch_kincaid',
    'punctuation_count', 'punctuation_density', 'ai_ratio', 'temp', 'misspelling_rate', 'pos_counts', 'pos_density'
    
]

df = df.drop(columns=columns_to_drop, axis=1)

print("Remaining columns in the DataFrame:")
print(df.columns)
# Out:
# Remaining columns in the DataFrame:
# Index(['essay_id', 'text', 'source', 'generated', 'vocabulary_richness',
#        'gunning_fog', 'smog_index', 'polarity', 'subjectivity', 'noun_density',
#        'verb_density', 'adjective_density', 'adverb_density', 'perplexity'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler


numeric_columns = df.select_dtypes(include=[np.number]).columns
df_numeric = df[numeric_columns]

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_numeric)

pca = PCA()
pca_data = pca.fit_transform(scaled_data)


explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance_ratio)

plt.figure(figsize=(10, 6))
plt.bar(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, alpha=0.6, label='Individual explained variance')
plt.step(range(1, len(cumulative_variance) + 1), cumulative_variance, where='mid', label='Cumulative explained variance', color='red')

plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('PCA: Explained Variance Ratio and Cumulative Variance')
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

n_components_95 = np.argmax(cumulative_variance >= 0.95) + 1
print(f"Number of components explaining at least 95% variance: {n_components_95}")
# Out:
# Number of components explaining at least 95% variance: 9

# %%
# Calculate punctuation rate
# df['punctuation_rate'] = df['text'].apply(lambda x: sum(1 for char in x if char in string.punctuation) / len(x.split()) if len(x.split()) > 0 else 0)

# %%
from sklearn.decomposition import PCA
pca_9 = PCA(n_components=9)

reduced_data = pca_9.fit_transform(scaled_data)

reduced_df = pd.DataFrame(reduced_data, columns=[f'PC{i+1}' for i in range(9)])

print(reduced_df.head())
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -1.299589 -1.544884  0.616784 -0.745889  0.201032 -0.970374 -0.312874
# 1 -2.290503  0.324305  0.006133 -0.213602  0.253705 -0.595827 -0.477839
# 2 -1.348318 -0.270886 -0.692341 -1.163940 -0.602528  0.659894  0.524783
# 3 -0.490330  1.193091 -0.164686 -0.475832 -0.163446  0.188114  0.313546
# 4 -3.842052  0.908197  0.026487 -0.346311  1.696407  0.077545  0.515282
#
#         PC8       PC9
# 0  0.968355 -0.402577
# 1  0.032178 -0.511274
# 2  0.259799 -1.019945
# 3 -0.926487 -0.941445
# 4 -0.791881  0.859469

# %%
loadings = pd.DataFrame(
    pca_9.components_, 
    columns=df_numeric.columns,  
    index=[f'PC{i+1}' for i in range(9)] 
)

print("PCA Loadings:")
print(loadings)

top_features_per_pc = {}
for pc in loadings.index:
    top_features = loadings.loc[pc].abs().sort_values(ascending=False).head(3)  # Top 3 features
    top_features_per_pc[pc] = top_features.index.tolist()

print("\nTop Contributing Features for Each Principal Component:")
for pc, features in top_features_per_pc.items():
    print(f"{pc}: {features}")
# Out:
# PCA Loadings:
#      vocabulary_richness  gunning_fog  smog_index  polarity  subjectivity  \
# PC1             0.324009     0.242202    0.438181 -0.069667     -0.117201
# PC2            -0.205342     0.015242    0.189610  0.574583      0.562543
# PC3             0.266313     0.313938   -0.071141  0.380172      0.371737
# PC4            -0.060823     0.576134    0.267743 -0.320676      0.115017
# PC5            -0.465678     0.616081    0.007692  0.071532     -0.230641
# PC6            -0.263391    -0.077149    0.036032  0.342543     -0.481495
# PC7             0.524699     0.180659   -0.056039  0.483573     -0.442158
# PC8             0.431847     0.056471   -0.025938 -0.239916      0.164098
# PC9            -0.061003    -0.296976    0.802682  0.058201     -0.051858
#
#      noun_density  verb_density  adjective_density  adverb_density  perplexity
# PC1      0.471094     -0.437257           0.335069       -0.316754   -0.006091
# PC2     -0.098446     -0.061543           0.171396       -0.141909   -0.460496
# PC3      0.035849      0.061935          -0.073480        0.069012    0.726263
# PC4     -0.279544      0.117898           0.308951        0.527033   -0.106599
# PC5      0.118806      0.156668          -0.397152       -0.383993   -0.037107
# PC6     -0.258437      0.163974           0.622106       -0.133680    0.275022
# PC7     -0.000447      0.137873          -0.177615        0.282614   -0.359360
# PC8     -0.198219      0.605749           0.147288       -0.531795   -0.120149
# PC9      0.066879      0.364077          -0.292074        0.112316    0.150873
#
# Top Contributing Features for Each Principal Component:
# PC1: ['noun_density', 'smog_index', 'verb_density']
# PC2: ['polarity', 'subjectivity', 'perplexity']
# PC3: ['perplexity', 'polarity', 'subjectivity']
# PC4: ['gunning_fog', 'adverb_density', 'polarity']
# PC5: ['gunning_fog', 'vocabulary_richness', 'adjective_density']
# PC6: ['adjective_density', 'subjectivity', 'polarity']
# PC7: ['vocabulary_richness', 'polarity', 'subjectivity']
# PC8: ['verb_density', 'adverb_density', 'vocabulary_richness']
# PC9: ['smog_index', 'verb_density', 'gunning_fog']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(loadings.abs(), cmap="coolwarm", annot=True, fmt=".2f")
plt.title("PCA Feature Loadings (Absolute Values)")
plt.xlabel("Features")
plt.ylabel("Principal Components")
plt.show()

# %%
#after pca

columns_to_drop = [
    'vocabulary_richness', 'polarity', 'subjectivity',
    'noun_density', 'verb_density', 'adjective_density', 'adverb_density', 

]

# Drop the selected columns
df = df.drop(columns=columns_to_drop, axis=1)

# Print the remaining columns to verify
print("Remaining columns in the DataFrame:")
print(df.columns)
# Out:
# Remaining columns in the DataFrame:
# Index(['essay_id', 'text', 'source', 'generated', 'gunning_fog', 'smog_index',
#        'perplexity'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
df.columns
# Out:
# Index(['essay_id', 'text', 'source', 'generated', 'gunning_fog', 'smog_index',
#        'perplexity'],
#       dtype='object')

# %%
df = df[df['generated'] != 'generated']

# %%
print(df['generated'].unique())
# Out:
# ['0' '1']

# %%
count_generated_1 = df[df['generated'] == '1'].shape[0]

count_generated_0 = df[df['generated'] == '0'].shape[0]

print(f"Count of generated == 1: {count_generated_1}")
print(f"Count of generated == 0: {count_generated_0}")
# Out:
# Count of generated == 1: 3984
# Count of generated == 0: 5626

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9610 entries, 0 to 9610
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   essay_id     9610 non-null   object
#  1   text         9610 non-null   object
#  2   source       9610 non-null   object
#  3   generated    9610 non-null   object
#  4   gunning_fog  9610 non-null   float64
#  5   smog_index   9610 non-null   float64
#  6   perplexity   9610 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 600.6+ KB

# %%
y = df['generated'].astype(int)
X = df.drop(columns=['generated', 'essay_id', 'text', 'source']).fillna(0.0)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=42)


from sklearn.preprocessing import StandardScaler

readability_metrics = ['gunning_fog', 'smog_index', 'perplexity']

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[readability_metrics])
X_val_scaled = scaler.transform(X_val[readability_metrics])
X_test_scaled = scaler.transform(X_test[readability_metrics])

X_train = pd.DataFrame(X_train_scaled, columns=readability_metrics, index=X_train.index)
X_val = pd.DataFrame(X_val_scaled, columns=readability_metrics, index=X_val.index)
X_test = pd.DataFrame(X_test_scaled, columns=readability_metrics, index=X_test.index)

# %%
print(X_train.dtypes)
# Out:
# gunning_fog    float64
# smog_index     float64
# perplexity     float64
# dtype: object

# %%
print(y_train.unique())
print(y_val.unique())
# Out:
# [0 1]
# [0 1]

# %%
X_train = X_train.fillna(0.0)
X_val = X_val.fillna(0.0)

# %%
print(X_train.isna().sum().sum())  # Should output 0
print(X_val.isna().sum().sum())    # Should output 0
print(y_train.isna().sum())        # Should output 0
print(y_val.isna().sum())          # Should output 0
# Out:
# 0
# 0
# 0
# 0

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report
import matplotlib.pyplot as plt


dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)


import xgboost as xgb

params = {
    'objective': 'binary:logistic',  
    'learning_rate': 0.0001,         
    'max_depth': 3,                  
    'min_child_weight': 20,          
    'subsample': 0.75,                
    'colsample_bytree': 0.75,         
    'eval_metric': 'logloss',        
    'lambda': 30,                    
    'alpha': 25,                     
    'booster': 'dart',               
    'rate_drop': 0.5,                
    'scale_pos_weight': len(y_train[y_train == 0]) / len(y_train[y_train == 1]),
    'skip_drop': 0.5    
}          

bst = xgb.train(
    params,                          
    dtrain,                          
    num_boost_round=1500,            
    evals=[(dval, 'validation')],    
    early_stopping_rounds=10,        
    verbose_eval=True                
)


y_val_pred = bst.predict(dval)
y_val_pred_binary = (y_val_pred > 0.5).astype(int)

accuracy = accuracy_score(y_val, y_val_pred_binary)
roc_auc = roc_auc_score(y_val, y_val_pred)
report = classification_report(y_val, y_val_pred_binary)

print(f"Validation Accuracy: {accuracy}")
print(f"Validation ROC-AUC: {roc_auc}")
print("Classification Report:\n", report)

xgb.plot_importance(bst)
plt.title("Feature Importance")
plt.show()
# Out:
# [0]	validation-logloss:0.69309
# [1]	validation-logloss:0.69303
# [2]	validation-logloss:0.69299
# [3]	validation-logloss:0.69294
# [4]	validation-logloss:0.69288
# [5]	validation-logloss:0.69286
# [6]	validation-logloss:0.69280
# [7]	validation-logloss:0.69278
# [8]	validation-logloss:0.69273
# [9]	validation-logloss:0.69270
# [10]	validation-logloss:0.69268
# [11]	validation-logloss:0.69265
# [12]	validation-logloss:0.69261
# [13]	validation-logloss:0.69255
# [14]	validation-logloss:0.69249
# [15]	validation-logloss:0.69248
# [16]	validation-logloss:0.69243
# [17]	validation-logloss:0.69242
# [18]	validation-logloss:0.69242
# [19]	validation-logloss:0.69241
# [20]	validation-logloss:0.69235
# [21]	validation-logloss:0.69235
# [22]	validation-logloss:0.69234
# [23]	validation-logloss:0.69234
# [24]	validation-logloss:0.69233
# [25]	validation-logloss:0.69227
# [26]	validation-logloss:0.69227
# [27]	validation-logloss:0.69227
# [28]	validation-logloss:0.69222
# [29]	validation-logloss:0.69221
# [30]	validation-logloss:0.69215
# [31]	validation-logloss:0.69215
# [32]	validation-logloss:0.69215
# [33]	validation-logloss:0.69214
# [34]	validation-logloss:0.69211
# [35]	validation-logloss:0.69208
# [36]	validation-logloss:0.69207
# [37]	validation-logloss:0.69204
# [38]	validation-logloss:0.69199
# [39]	validation-logloss:0.69194
# [40]	validation-logloss:0.69194
# [41]	validation-logloss:0.69190
# [42]	validation-logloss:0.69190
# [43]	validation-logloss:0.69185
# [44]	validation-logloss:0.69180
# [45]	validation-logloss:0.69180
# [46]	validation-logloss:0.69179
# [47]	validation-logloss:0.69176
# [48]	validation-logloss:0.69176
# [49]	validation-logloss:0.69176
# [50]	validation-logloss:0.69176
# [51]	validation-logloss:0.69170
# [52]	validation-logloss:0.69170
# [53]	validation-logloss:0.69167
# [54]	validation-logloss:0.69163
# [55]	validation-logloss:0.69163
# [56]	validation-logloss:0.69163
# [57]	validation-logloss:0.69163
# [58]	validation-logloss:0.69157
# [59]	validation-logloss:0.69151
# [60]	validation-logloss:0.69151
# [61]	validation-logloss:0.69146
# [62]	validation-logloss:0.69141
# [63]	validation-logloss:0.69141
# [64]	validation-logloss:0.69137
# [65]	validation-logloss:0.69134
# [66]	validation-logloss:0.69129
# [67]	validation-logloss:0.69129
# [68]	validation-logloss:0.69123
# [69]	validation-logloss:0.69118
# [70]	validation-logloss:0.69115
# [71]	validation-logloss:0.69114
# [72]	validation-logloss:0.69108
# [73]	validation-logloss:0.69103
# [74]	validation-logloss:0.69103
# [75]	validation-logloss:0.69098
# [76]	validation-logloss:0.69093
# [77]	validation-logloss:0.69093
# [78]	validation-logloss:0.69090
# [79]	validation-logloss:0.69085
# [80]	validation-logloss:0.69079
# [81]	validation-logloss:0.69075
# [82]	validation-logloss:0.69075
# [83]	validation-logloss:0.69072
# [84]	validation-logloss:0.69072
# [85]	validation-logloss:0.69072
# [86]	validation-logloss:0.69066
# [87]	validation-logloss:0.69063
# [88]	validation-logloss:0.69063
# [89]	validation-logloss:0.69057
# [90]	validation-logloss:0.69054
# [91]	validation-logloss:0.69048
# [92]	validation-logloss:0.69043
# [93]	validation-logloss:0.69043
# [94]	validation-logloss:0.69043
# [95]	validation-logloss:0.69039
# [96]	validation-logloss:0.69034
# [97]	validation-logloss:0.69031
# [98]	validation-logloss:0.69031
# [99]	validation-logloss:0.69027
# [100]	validation-logloss:0.69021
# [101]	validation-logloss:0.69021
# [102]	validation-logloss:0.69021
# [103]	validation-logloss:0.69021
# [104]	validation-logloss:0.69016
# [105]	validation-logloss:0.69016
# [106]	validation-logloss:0.69016
# [107]	validation-logloss:0.69016
# [108]	validation-logloss:0.69010
# [109]	validation-logloss:0.69010
# [110]	validation-logloss:0.69006
# [111]	validation-logloss:0.69006
# [112]	validation-logloss:0.69000
# [113]	validation-logloss:0.69000
# [114]	validation-logloss:0.69000
# [115]	validation-logloss:0.69000
# [116]	validation-logloss:0.68995
# [117]	validation-logloss:0.68989
# [118]	validation-logloss:0.68983
# [119]	validation-logloss:0.68983
# [120]	validation-logloss:0.68983
# [121]	validation-logloss:0.68978
# [122]	validation-logloss:0.68972
# [123]	validation-logloss:0.68972
# [124]	validation-logloss:0.68968
# [125]	validation-logloss:0.68962
# [126]	validation-logloss:0.68957
# [127]	validation-logloss:0.68957
# [128]	validation-logloss:0.68957
# [129]	validation-logloss:0.68952
# [130]	validation-logloss:0.68952
# [131]	validation-logloss:0.68952
# [132]	validation-logloss:0.68948
# [133]	validation-logloss:0.68948
# [134]	validation-logloss:0.68948
# [135]	validation-logloss:0.68948
# [136]	validation-logloss:0.68948
# [137]	validation-logloss:0.68945
# [138]	validation-logloss:0.68945
# [139]	validation-logloss:0.68940
# [140]	validation-logloss:0.68940
# [141]	validation-logloss:0.68940
# [142]	validation-logloss:0.68939
# [143]	validation-logloss:0.68933
# [144]	validation-logloss:0.68933
# [145]	validation-logloss:0.68928
# [146]	validation-logloss:0.68928
# [147]	validation-logloss:0.68928
# [148]	validation-logloss:0.68928
# [149]	validation-logloss:0.68928
# [150]	validation-logloss:0.68923
# [151]	validation-logloss:0.68923
# [152]	validation-logloss:0.68923
# [153]	validation-logloss:0.68923
# [154]	validation-logloss:0.68923
# [155]	validation-logloss:0.68918
# [156]	validation-logloss:0.68912
# [157]	validation-logloss:0.68906
# [158]	validation-logloss:0.68906
# [159]	validation-logloss:0.68901
# [160]	validation-logloss:0.68901
# [161]	validation-logloss:0.68901
# [162]	validation-logloss:0.68901
# [163]	validation-logloss:0.68896
# [164]	validation-logloss:0.68893
# [165]	validation-logloss:0.68888
# [166]	validation-logloss:0.68882
# [167]	validation-logloss:0.68882
# [168]	validation-logloss:0.68878
# [169]	validation-logloss:0.68878
# [170]	validation-logloss:0.68874
# [171]	validation-logloss:0.68873
# [172]	validation-logloss:0.68869
# [173]	validation-logloss:0.68868
# [174]	validation-logloss:0.68863
# [175]	validation-logloss:0.68863
# [176]	validation-logloss:0.68863
# [177]	validation-logloss:0.68860
# [178]	validation-logloss:0.68854
# [179]	validation-logloss:0.68851
# [180]	validation-logloss:0.68850
# [181]	validation-logloss:0.68844
# [182]	validation-logloss:0.68844
# [183]	validation-logloss:0.68839
# [184]	validation-logloss:0.68839
# [185]	validation-logloss:0.68839
# [186]	validation-logloss:0.68839
# [187]	validation-logloss:0.68833
# [188]	validation-logloss:0.68833
# [189]	validation-logloss:0.68830
# [190]	validation-logloss:0.68830
# [191]	validation-logloss:0.68830
# [192]	validation-logloss:0.68830
# [193]	validation-logloss:0.68830
# [194]	validation-logloss:0.68826
# [195]	validation-logloss:0.68826
# [196]	validation-logloss:0.68820
# [197]	validation-logloss:0.68820
# [198]	validation-logloss:0.68814
# [199]	validation-logloss:0.68814
# [200]	validation-logloss:0.68811
# [201]	validation-logloss:0.68807
# [202]	validation-logloss:0.68807
# [203]	validation-logloss:0.68802
# [204]	validation-logloss:0.68802
# [205]	validation-logloss:0.68796
# [206]	validation-logloss:0.68796
# [207]	validation-logloss:0.68791
# [208]	validation-logloss:0.68785
# [209]	validation-logloss:0.68784
# [210]	validation-logloss:0.68784
# [211]	validation-logloss:0.68784
# [212]	validation-logloss:0.68779
# [213]	validation-logloss:0.68775
# [214]	validation-logloss:0.68770
# [215]	validation-logloss:0.68770
# [216]	validation-logloss:0.68765
# [217]	validation-logloss:0.68765
# [218]	validation-logloss:0.68764
# [219]	validation-logloss:0.68764
# [220]	validation-logloss:0.68764
# [221]	validation-logloss:0.68764
# [222]	validation-logloss:0.68759
# [223]	validation-logloss:0.68756
# [224]	validation-logloss:0.68756
# [225]	validation-logloss:0.68750
# [226]	validation-logloss:0.68750
# [227]	validation-logloss:0.68745
# [228]	validation-logloss:0.68745
# [229]	validation-logloss:0.68745
# [230]	validation-logloss:0.68739
# [231]	validation-logloss:0.68735
# [232]	validation-logloss:0.68735
# [233]	validation-logloss:0.68735
# [234]	validation-logloss:0.68732
# [235]	validation-logloss:0.68732
# [236]	validation-logloss:0.68729
# [237]	validation-logloss:0.68729
# [238]	validation-logloss:0.68729
# [239]	validation-logloss:0.68723
# [240]	validation-logloss:0.68723
# [241]	validation-logloss:0.68723
# [242]	validation-logloss:0.68718
# [243]	validation-logloss:0.68713
# [244]	validation-logloss:0.68713
# [245]	validation-logloss:0.68713
# [246]	validation-logloss:0.68713
# [247]	validation-logloss:0.68708
# [248]	validation-logloss:0.68708
# [249]	validation-logloss:0.68708
# [250]	validation-logloss:0.68704
# [251]	validation-logloss:0.68704
# [252]	validation-logloss:0.68704
# [253]	validation-logloss:0.68701
# [254]	validation-logloss:0.68701
# [255]	validation-logloss:0.68701
# [256]	validation-logloss:0.68701
# [257]	validation-logloss:0.68695
# [258]	validation-logloss:0.68695
# [259]	validation-logloss:0.68691
# [260]	validation-logloss:0.68691
# [261]	validation-logloss:0.68686
# [262]	validation-logloss:0.68683
# [263]	validation-logloss:0.68683
# [264]	validation-logloss:0.68678
# [265]	validation-logloss:0.68672
# [266]	validation-logloss:0.68667
# [267]	validation-logloss:0.68664
# [268]	validation-logloss:0.68664
# [269]	validation-logloss:0.68658
# [270]	validation-logloss:0.68653
# [271]	validation-logloss:0.68653
# [272]	validation-logloss:0.68653
# [273]	validation-logloss:0.68649
# [274]	validation-logloss:0.68649
# [275]	validation-logloss:0.68649
# [276]	validation-logloss:0.68646
# [277]	validation-logloss:0.68642
# [278]	validation-logloss:0.68636
# [279]	validation-logloss:0.68632
# [280]	validation-logloss:0.68632
# [281]	validation-logloss:0.68631
# [282]	validation-logloss:0.68626
# [283]	validation-logloss:0.68626
# [284]	validation-logloss:0.68622
# [285]	validation-logloss:0.68622
# [286]	validation-logloss:0.68622
# [287]	validation-logloss:0.68621
# [288]	validation-logloss:0.68621
# [289]	validation-logloss:0.68621
# [290]	validation-logloss:0.68618
# [291]	validation-logloss:0.68615
# [292]	validation-logloss:0.68615
# [293]	validation-logloss:0.68610
# [294]	validation-logloss:0.68605
# [295]	validation-logloss:0.68605
# [296]	validation-logloss:0.68600
# [297]	validation-logloss:0.68600
# [298]	validation-logloss:0.68597
# [299]	validation-logloss:0.68596
# [300]	validation-logloss:0.68596
# [301]	validation-logloss:0.68593
# [302]	validation-logloss:0.68593
# [303]	validation-logloss:0.68588
# [304]	validation-logloss:0.68588
# [305]	validation-logloss:0.68582
# [306]	validation-logloss:0.68582
# [307]	validation-logloss:0.68577
# [308]	validation-logloss:0.68577
# [309]	validation-logloss:0.68577
# [310]	validation-logloss:0.68577
# [311]	validation-logloss:0.68577
# [312]	validation-logloss:0.68574
# [313]	validation-logloss:0.68570
# [314]	validation-logloss:0.68570
# [315]	validation-logloss:0.68570
# [316]	validation-logloss:0.68570
# [317]	validation-logloss:0.68570
# [318]	validation-logloss:0.68567
# [319]	validation-logloss:0.68567
# [320]	validation-logloss:0.68567
# [321]	validation-logloss:0.68564
# [322]	validation-logloss:0.68564
# [323]	validation-logloss:0.68559
# [324]	validation-logloss:0.68555
# [325]	validation-logloss:0.68555
# [326]	validation-logloss:0.68552
# [327]	validation-logloss:0.68552
# [328]	validation-logloss:0.68548
# [329]	validation-logloss:0.68548
# [330]	validation-logloss:0.68543
# [331]	validation-logloss:0.68543
# [332]	validation-logloss:0.68538
# [333]	validation-logloss:0.68538
# [334]	validation-logloss:0.68532
# [335]	validation-logloss:0.68529
# [336]	validation-logloss:0.68526
# [337]	validation-logloss:0.68520
# [338]	validation-logloss:0.68520
# [339]	validation-logloss:0.68520
# [340]	validation-logloss:0.68515
# [341]	validation-logloss:0.68515
# [342]	validation-logloss:0.68509
# [343]	validation-logloss:0.68509
# [344]	validation-logloss:0.68504
# [345]	validation-logloss:0.68499
# [346]	validation-logloss:0.68499
# [347]	validation-logloss:0.68496
# [348]	validation-logloss:0.68491
# [349]	validation-logloss:0.68491
# [350]	validation-logloss:0.68491
# [351]	validation-logloss:0.68491
# [352]	validation-logloss:0.68485
# [353]	validation-logloss:0.68485
# [354]	validation-logloss:0.68485
# [355]	validation-logloss:0.68482
# [356]	validation-logloss:0.68482
# [357]	validation-logloss:0.68478
# [358]	validation-logloss:0.68478
# [359]	validation-logloss:0.68478
# [360]	validation-logloss:0.68473
# [361]	validation-logloss:0.68473
# [362]	validation-logloss:0.68470
# [363]	validation-logloss:0.68470
# [364]	validation-logloss:0.68465
# [365]	validation-logloss:0.68459
# [366]	validation-logloss:0.68459
# [367]	validation-logloss:0.68454
# [368]	validation-logloss:0.68454
# [369]	validation-logloss:0.68453
# [370]	validation-logloss:0.68449
# [371]	validation-logloss:0.68449
# [372]	validation-logloss:0.68443
# [373]	validation-logloss:0.68438
# [374]	validation-logloss:0.68438
# [375]	validation-logloss:0.68433
# [376]	validation-logloss:0.68433
# [377]	validation-logloss:0.68428
# [378]	validation-logloss:0.68422
# [379]	validation-logloss:0.68422
# [380]	validation-logloss:0.68422
# [381]	validation-logloss:0.68422
# [382]	validation-logloss:0.68417
# [383]	validation-logloss:0.68412
# [384]	validation-logloss:0.68409
# [385]	validation-logloss:0.68409
# [386]	validation-logloss:0.68409
# [387]	validation-logloss:0.68409
# [388]	validation-logloss:0.68409
# [389]	validation-logloss:0.68404
# [390]	validation-logloss:0.68404
# [391]	validation-logloss:0.68399
# [392]	validation-logloss:0.68394
# [393]	validation-logloss:0.68394
# [394]	validation-logloss:0.68394
# [395]	validation-logloss:0.68394
# [396]	validation-logloss:0.68394
# [397]	validation-logloss:0.68394
# [398]	validation-logloss:0.68394
# [399]	validation-logloss:0.68388
# [400]	validation-logloss:0.68388
# [401]	validation-logloss:0.68385
# [402]	validation-logloss:0.68379
# [403]	validation-logloss:0.68379
# [404]	validation-logloss:0.68375
# [405]	validation-logloss:0.68372
# [406]	validation-logloss:0.68366
# [407]	validation-logloss:0.68361
# [408]	validation-logloss:0.68356
# [409]	validation-logloss:0.68356
# [410]	validation-logloss:0.68356
# [411]	validation-logloss:0.68352
# [412]	validation-logloss:0.68352
# [413]	validation-logloss:0.68352
# [414]	validation-logloss:0.68347
# [415]	validation-logloss:0.68341
# [416]	validation-logloss:0.68336
# [417]	validation-logloss:0.68331
# [418]	validation-logloss:0.68331
# [419]	validation-logloss:0.68331
# [420]	validation-logloss:0.68331
# [421]	validation-logloss:0.68331
# [422]	validation-logloss:0.68326
# [423]	validation-logloss:0.68321
# [424]	validation-logloss:0.68315
# [425]	validation-logloss:0.68315
# [426]	validation-logloss:0.68315
# [427]	validation-logloss:0.68312
# [428]	validation-logloss:0.68312
# [429]	validation-logloss:0.68307
# [430]	validation-logloss:0.68307
# [431]	validation-logloss:0.68307
# [432]	validation-logloss:0.68307
# [433]	validation-logloss:0.68304
# [434]	validation-logloss:0.68299
# [435]	validation-logloss:0.68299
# [436]	validation-logloss:0.68295
# [437]	validation-logloss:0.68295
# [438]	validation-logloss:0.68290
# [439]	validation-logloss:0.68290
# [440]	validation-logloss:0.68286
# [441]	validation-logloss:0.68286
# [442]	validation-logloss:0.68283
# [443]	validation-logloss:0.68283
# [444]	validation-logloss:0.68280
# [445]	validation-logloss:0.68276
# [446]	validation-logloss:0.68276
# [447]	validation-logloss:0.68276
# [448]	validation-logloss:0.68271
# [449]	validation-logloss:0.68268
# [450]	validation-logloss:0.68268
# [451]	validation-logloss:0.68263
# [452]	validation-logloss:0.68258
# [453]	validation-logloss:0.68255
# [454]	validation-logloss:0.68250
# [455]	validation-logloss:0.68244
# [456]	validation-logloss:0.68244
# [457]	validation-logloss:0.68239
# [458]	validation-logloss:0.68239
# [459]	validation-logloss:0.68234
# [460]	validation-logloss:0.68230
# [461]	validation-logloss:0.68227
# [462]	validation-logloss:0.68221
# [463]	validation-logloss:0.68221
# [464]	validation-logloss:0.68221
# [465]	validation-logloss:0.68221
# [466]	validation-logloss:0.68221
# [467]	validation-logloss:0.68221
# [468]	validation-logloss:0.68215
# [469]	validation-logloss:0.68215
# [470]	validation-logloss:0.68209
# [471]	validation-logloss:0.68205
# [472]	validation-logloss:0.68201
# [473]	validation-logloss:0.68198
# [474]	validation-logloss:0.68198
# [475]	validation-logloss:0.68193
# [476]	validation-logloss:0.68193
# [477]	validation-logloss:0.68193
# [478]	validation-logloss:0.68193
# [479]	validation-logloss:0.68187
# [480]	validation-logloss:0.68187
# [481]	validation-logloss:0.68187
# [482]	validation-logloss:0.68187
# [483]	validation-logloss:0.68182
# [484]	validation-logloss:0.68182
# [485]	validation-logloss:0.68176
# [486]	validation-logloss:0.68173
# [487]	validation-logloss:0.68170
# [488]	validation-logloss:0.68170
# [489]	validation-logloss:0.68170
# [490]	validation-logloss:0.68165
# [491]	validation-logloss:0.68165
# [492]	validation-logloss:0.68161
# [493]	validation-logloss:0.68161
# [494]	validation-logloss:0.68161
# [495]	validation-logloss:0.68161
# [496]	validation-logloss:0.68158
# [497]	validation-logloss:0.68158
# [498]	validation-logloss:0.68158
# [499]	validation-logloss:0.68158
# [500]	validation-logloss:0.68155
# [501]	validation-logloss:0.68155
# [502]	validation-logloss:0.68151
# [503]	validation-logloss:0.68151
# [504]	validation-logloss:0.68151
# [505]	validation-logloss:0.68151
# [506]	validation-logloss:0.68146
# [507]	validation-logloss:0.68146
# [508]	validation-logloss:0.68146
# [509]	validation-logloss:0.68141
# [510]	validation-logloss:0.68136
# [511]	validation-logloss:0.68132
# [512]	validation-logloss:0.68127
# [513]	validation-logloss:0.68126
# [514]	validation-logloss:0.68121
# [515]	validation-logloss:0.68117
# [516]	validation-logloss:0.68113
# [517]	validation-logloss:0.68112
# [518]	validation-logloss:0.68112
# [519]	validation-logloss:0.68108
# [520]	validation-logloss:0.68104
# [521]	validation-logloss:0.68104
# [522]	validation-logloss:0.68100
# [523]	validation-logloss:0.68100
# [524]	validation-logloss:0.68096
# [525]	validation-logloss:0.68096
# [526]	validation-logloss:0.68090
# [527]	validation-logloss:0.68090
# [528]	validation-logloss:0.68090
# [529]	validation-logloss:0.68090
# [530]	validation-logloss:0.68090
# [531]	validation-logloss:0.68090
# [532]	validation-logloss:0.68090
# [533]	validation-logloss:0.68087
# [534]	validation-logloss:0.68087
# [535]	validation-logloss:0.68087
# [536]	validation-logloss:0.68082
# [537]	validation-logloss:0.68077
# [538]	validation-logloss:0.68072
# [539]	validation-logloss:0.68068
# [540]	validation-logloss:0.68064
# [541]	validation-logloss:0.68058
# [542]	validation-logloss:0.68055
# [543]	validation-logloss:0.68055
# [544]	validation-logloss:0.68055
# [545]	validation-logloss:0.68049
# [546]	validation-logloss:0.68046
# [547]	validation-logloss:0.68043
# [548]	validation-logloss:0.68038
# [549]	validation-logloss:0.68038
# [550]	validation-logloss:0.68035
# [551]	validation-logloss:0.68031
# [552]	validation-logloss:0.68025
# [553]	validation-logloss:0.68025
# [554]	validation-logloss:0.68025
# [555]	validation-logloss:0.68021
# [556]	validation-logloss:0.68015
# [557]	validation-logloss:0.68015
# [558]	validation-logloss:0.68010
# [559]	validation-logloss:0.68010
# [560]	validation-logloss:0.68005
# [561]	validation-logloss:0.68002
# [562]	validation-logloss:0.67996
# [563]	validation-logloss:0.67990
# [564]	validation-logloss:0.67990
# [565]	validation-logloss:0.67990
# [566]	validation-logloss:0.67984
# [567]	validation-logloss:0.67984
# [568]	validation-logloss:0.67984
# [569]	validation-logloss:0.67984
# [570]	validation-logloss:0.67979
# [571]	validation-logloss:0.67976
# [572]	validation-logloss:0.67976
# [573]	validation-logloss:0.67973
# [574]	validation-logloss:0.67973
# [575]	validation-logloss:0.67973
# [576]	validation-logloss:0.67973
# [577]	validation-logloss:0.67968
# [578]	validation-logloss:0.67962
# [579]	validation-logloss:0.67962
# [580]	validation-logloss:0.67962
# [581]	validation-logloss:0.67962
# [582]	validation-logloss:0.67959
# [583]	validation-logloss:0.67954
# [584]	validation-logloss:0.67954
# [585]	validation-logloss:0.67948
# [586]	validation-logloss:0.67948
# [587]	validation-logloss:0.67948
# [588]	validation-logloss:0.67948
# [589]	validation-logloss:0.67943
# [590]	validation-logloss:0.67943
# [591]	validation-logloss:0.67938
# [592]	validation-logloss:0.67933
# [593]	validation-logloss:0.67933
# [594]	validation-logloss:0.67933
# [595]	validation-logloss:0.67928
# [596]	validation-logloss:0.67923
# [597]	validation-logloss:0.67918
# [598]	validation-logloss:0.67914
# [599]	validation-logloss:0.67908
# [600]	validation-logloss:0.67908
# [601]	validation-logloss:0.67908
# [602]	validation-logloss:0.67908
# [603]	validation-logloss:0.67908
# [604]	validation-logloss:0.67908
# [605]	validation-logloss:0.67908
# [606]	validation-logloss:0.67908
# [607]	validation-logloss:0.67908
# [608]	validation-logloss:0.67904
# [609]	validation-logloss:0.67901
# [610]	validation-logloss:0.67901
# [611]	validation-logloss:0.67898
# [612]	validation-logloss:0.67893
# [613]	validation-logloss:0.67890
# [614]	validation-logloss:0.67890
# [615]	validation-logloss:0.67890
# [616]	validation-logloss:0.67884
# [617]	validation-logloss:0.67884
# [618]	validation-logloss:0.67884
# [619]	validation-logloss:0.67881
# [620]	validation-logloss:0.67881
# [621]	validation-logloss:0.67876
# [622]	validation-logloss:0.67871
# [623]	validation-logloss:0.67865
# [624]	validation-logloss:0.67865
# [625]	validation-logloss:0.67865
# [626]	validation-logloss:0.67865
# [627]	validation-logloss:0.67860
# [628]	validation-logloss:0.67860
# [629]	validation-logloss:0.67856
# [630]	validation-logloss:0.67856
# [631]	validation-logloss:0.67851
# [632]	validation-logloss:0.67851
# [633]	validation-logloss:0.67851
# [634]	validation-logloss:0.67845
# [635]	validation-logloss:0.67845
# [636]	validation-logloss:0.67845
# [637]	validation-logloss:0.67845
# [638]	validation-logloss:0.67840
# [639]	validation-logloss:0.67834
# [640]	validation-logloss:0.67831
# [641]	validation-logloss:0.67828
# [642]	validation-logloss:0.67822
# [643]	validation-logloss:0.67822
# [644]	validation-logloss:0.67819
# [645]	validation-logloss:0.67819
# [646]	validation-logloss:0.67819
# [647]	validation-logloss:0.67819
# [648]	validation-logloss:0.67818
# [649]	validation-logloss:0.67815
# [650]	validation-logloss:0.67809
# [651]	validation-logloss:0.67805
# [652]	validation-logloss:0.67801
# [653]	validation-logloss:0.67801
# [654]	validation-logloss:0.67801
# [655]	validation-logloss:0.67795
# [656]	validation-logloss:0.67795
# [657]	validation-logloss:0.67795
# [658]	validation-logloss:0.67795
# [659]	validation-logloss:0.67795
# [660]	validation-logloss:0.67791
# [661]	validation-logloss:0.67791
# [662]	validation-logloss:0.67785
# [663]	validation-logloss:0.67780
# [664]	validation-logloss:0.67775
# [665]	validation-logloss:0.67775
# [666]	validation-logloss:0.67772
# [667]	validation-logloss:0.67772
# [668]	validation-logloss:0.67772
# [669]	validation-logloss:0.67772
# [670]	validation-logloss:0.67772
# [671]	validation-logloss:0.67769
# [672]	validation-logloss:0.67769
# [673]	validation-logloss:0.67769
# [674]	validation-logloss:0.67763
# [675]	validation-logloss:0.67758
# [676]	validation-logloss:0.67758
# [677]	validation-logloss:0.67755
# [678]	validation-logloss:0.67749
# [679]	validation-logloss:0.67749
# [680]	validation-logloss:0.67746
# [681]	validation-logloss:0.67746
# [682]	validation-logloss:0.67746
# [683]	validation-logloss:0.67746
# [684]	validation-logloss:0.67740
# [685]	validation-logloss:0.67740
# [686]	validation-logloss:0.67736
# [687]	validation-logloss:0.67736
# [688]	validation-logloss:0.67736
# [689]	validation-logloss:0.67732
# [690]	validation-logloss:0.67727
# [691]	validation-logloss:0.67722
# [692]	validation-logloss:0.67719
# [693]	validation-logloss:0.67719
# [694]	validation-logloss:0.67719
# [695]	validation-logloss:0.67719
# [696]	validation-logloss:0.67713
# [697]	validation-logloss:0.67713
# [698]	validation-logloss:0.67707
# [699]	validation-logloss:0.67702
# [700]	validation-logloss:0.67702
# [701]	validation-logloss:0.67697
# [702]	validation-logloss:0.67696
# [703]	validation-logloss:0.67693
# [704]	validation-logloss:0.67688
# [705]	validation-logloss:0.67688
# [706]	validation-logloss:0.67688
# [707]	validation-logloss:0.67683
# [708]	validation-logloss:0.67683
# [709]	validation-logloss:0.67678
# [710]	validation-logloss:0.67675
# [711]	validation-logloss:0.67670
# [712]	validation-logloss:0.67667
# [713]	validation-logloss:0.67667
# [714]	validation-logloss:0.67662
# [715]	validation-logloss:0.67662
# [716]	validation-logloss:0.67662
# [717]	validation-logloss:0.67656
# [718]	validation-logloss:0.67656
# [719]	validation-logloss:0.67653
# [720]	validation-logloss:0.67648
# [721]	validation-logloss:0.67648
# [722]	validation-logloss:0.67648
# [723]	validation-logloss:0.67648
# [724]	validation-logloss:0.67643
# [725]	validation-logloss:0.67642
# [726]	validation-logloss:0.67642
# [727]	validation-logloss:0.67639
# [728]	validation-logloss:0.67636
# [729]	validation-logloss:0.67631
# [730]	validation-logloss:0.67628
# [731]	validation-logloss:0.67625
# [732]	validation-logloss:0.67625
# [733]	validation-logloss:0.67619
# [734]	validation-logloss:0.67614
# [735]	validation-logloss:0.67614
# [736]	validation-logloss:0.67608
# [737]	validation-logloss:0.67608
# [738]	validation-logloss:0.67603
# [739]	validation-logloss:0.67599
# [740]	validation-logloss:0.67599
# [741]	validation-logloss:0.67596
# [742]	validation-logloss:0.67593
# [743]	validation-logloss:0.67593
# [744]	validation-logloss:0.67593
# [745]	validation-logloss:0.67593
# [746]	validation-logloss:0.67593
# [747]	validation-logloss:0.67593
# [748]	validation-logloss:0.67593
# [749]	validation-logloss:0.67589
# [750]	validation-logloss:0.67584
# [751]	validation-logloss:0.67584
# [752]	validation-logloss:0.67584
# [753]	validation-logloss:0.67579
# [754]	validation-logloss:0.67579
# [755]	validation-logloss:0.67579
# [756]	validation-logloss:0.67574
# [757]	validation-logloss:0.67568
# [758]	validation-logloss:0.67565
# [759]	validation-logloss:0.67565
# [760]	validation-logloss:0.67562
# [761]	validation-logloss:0.67562
# [762]	validation-logloss:0.67557
# [763]	validation-logloss:0.67554
# [764]	validation-logloss:0.67554
# [765]	validation-logloss:0.67551
# [766]	validation-logloss:0.67551
# [767]	validation-logloss:0.67546
# [768]	validation-logloss:0.67540
# [769]	validation-logloss:0.67540
# [770]	validation-logloss:0.67535
# [771]	validation-logloss:0.67535
# [772]	validation-logloss:0.67529
# [773]	validation-logloss:0.67529
# [774]	validation-logloss:0.67526
# [775]	validation-logloss:0.67521
# [776]	validation-logloss:0.67521
# [777]	validation-logloss:0.67521
# [778]	validation-logloss:0.67521
# [779]	validation-logloss:0.67521
# [780]	validation-logloss:0.67518
# [781]	validation-logloss:0.67518
# [782]	validation-logloss:0.67514
# [783]	validation-logloss:0.67509
# [784]	validation-logloss:0.67509
# [785]	validation-logloss:0.67509
# [786]	validation-logloss:0.67505
# [787]	validation-logloss:0.67505
# [788]	validation-logloss:0.67505
# [789]	validation-logloss:0.67505
# [790]	validation-logloss:0.67505
# [791]	validation-logloss:0.67501
# [792]	validation-logloss:0.67498
# [793]	validation-logloss:0.67498
# [794]	validation-logloss:0.67498
# [795]	validation-logloss:0.67497
# [796]	validation-logloss:0.67497
# [797]	validation-logloss:0.67497
# [798]	validation-logloss:0.67497
# [799]	validation-logloss:0.67497
# [800]	validation-logloss:0.67497
# [801]	validation-logloss:0.67493
# [802]	validation-logloss:0.67493
# [803]	validation-logloss:0.67493
# [804]	validation-logloss:0.67493
# [805]	validation-logloss:0.67487
# [806]	validation-logloss:0.67487
# [807]	validation-logloss:0.67487
# [808]	validation-logloss:0.67487
# [809]	validation-logloss:0.67487
# [810]	validation-logloss:0.67487
# [811]	validation-logloss:0.67482
# [812]	validation-logloss:0.67477
# [813]	validation-logloss:0.67473
# [814]	validation-logloss:0.67468
# [815]	validation-logloss:0.67463
# [816]	validation-logloss:0.67457
# [817]	validation-logloss:0.67453
# [818]	validation-logloss:0.67453
# [819]	validation-logloss:0.67447
# [820]	validation-logloss:0.67447
# [821]	validation-logloss:0.67447
# [822]	validation-logloss:0.67447
# [823]	validation-logloss:0.67447
# [824]	validation-logloss:0.67447
# [825]	validation-logloss:0.67447
# [826]	validation-logloss:0.67442
# [827]	validation-logloss:0.67439
# [828]	validation-logloss:0.67439
# [829]	validation-logloss:0.67439
# [830]	validation-logloss:0.67439
# [831]	validation-logloss:0.67433
# [832]	validation-logloss:0.67428
# [833]	validation-logloss:0.67427
# [834]	validation-logloss:0.67423
# [835]	validation-logloss:0.67423
# [836]	validation-logloss:0.67423
# [837]	validation-logloss:0.67417
# [838]	validation-logloss:0.67414
# [839]	validation-logloss:0.67408
# [840]	validation-logloss:0.67405
# [841]	validation-logloss:0.67405
# [842]	validation-logloss:0.67405
# [843]	validation-logloss:0.67400
# [844]	validation-logloss:0.67400
# [845]	validation-logloss:0.67400
# [846]	validation-logloss:0.67397
# [847]	validation-logloss:0.67397
# [848]	validation-logloss:0.67397
# [849]	validation-logloss:0.67391
# [850]	validation-logloss:0.67388
# [851]	validation-logloss:0.67382
# [852]	validation-logloss:0.67382
# [853]	validation-logloss:0.67382
# [854]	validation-logloss:0.67382
# [855]	validation-logloss:0.67377
# [856]	validation-logloss:0.67372
# [857]	validation-logloss:0.67372
# [858]	validation-logloss:0.67372
# [859]	validation-logloss:0.67372
# [860]	validation-logloss:0.67366
# [861]	validation-logloss:0.67366
# [862]	validation-logloss:0.67363
# [863]	validation-logloss:0.67363
# [864]	validation-logloss:0.67363
# [865]	validation-logloss:0.67363
# [866]	validation-logloss:0.67363
# [867]	validation-logloss:0.67363
# [868]	validation-logloss:0.67358
# [869]	validation-logloss:0.67353
# [870]	validation-logloss:0.67350
# [871]	validation-logloss:0.67350
# [872]	validation-logloss:0.67345
# [873]	validation-logloss:0.67345
# [874]	validation-logloss:0.67345
# [875]	validation-logloss:0.67341
# [876]	validation-logloss:0.67341
# [877]	validation-logloss:0.67341
# [878]	validation-logloss:0.67337
# [879]	validation-logloss:0.67337
# [880]	validation-logloss:0.67337
# [881]	validation-logloss:0.67332
# [882]	validation-logloss:0.67328
# [883]	validation-logloss:0.67328
# [884]	validation-logloss:0.67328
# [885]	validation-logloss:0.67324
# [886]	validation-logloss:0.67324
# [887]	validation-logloss:0.67324
# [888]	validation-logloss:0.67319
# [889]	validation-logloss:0.67314
# [890]	validation-logloss:0.67314
# [891]	validation-logloss:0.67311
# [892]	validation-logloss:0.67305
# [893]	validation-logloss:0.67301
# [894]	validation-logloss:0.67301
# [895]	validation-logloss:0.67296
# [896]	validation-logloss:0.67296
# [897]	validation-logloss:0.67296
# [898]	validation-logloss:0.67290
# [899]	validation-logloss:0.67284
# [900]	validation-logloss:0.67284
# [901]	validation-logloss:0.67281
# [902]	validation-logloss:0.67275
# [903]	validation-logloss:0.67271
# [904]	validation-logloss:0.67268
# [905]	validation-logloss:0.67268
# [906]	validation-logloss:0.67262
# [907]	validation-logloss:0.67256
# [908]	validation-logloss:0.67251
# [909]	validation-logloss:0.67246
# [910]	validation-logloss:0.67246
# [911]	validation-logloss:0.67246
# [912]	validation-logloss:0.67246
# [913]	validation-logloss:0.67246
# [914]	validation-logloss:0.67240
# [915]	validation-logloss:0.67234
# [916]	validation-logloss:0.67234
# [917]	validation-logloss:0.67234
# [918]	validation-logloss:0.67230
# [919]	validation-logloss:0.67230
# [920]	validation-logloss:0.67224
# [921]	validation-logloss:0.67221
# [922]	validation-logloss:0.67216
# [923]	validation-logloss:0.67216
# [924]	validation-logloss:0.67216
# [925]	validation-logloss:0.67211
# [926]	validation-logloss:0.67211
# [927]	validation-logloss:0.67211
# [928]	validation-logloss:0.67211
# [929]	validation-logloss:0.67211
# [930]	validation-logloss:0.67211
# [931]	validation-logloss:0.67208
# [932]	validation-logloss:0.67205
# [933]	validation-logloss:0.67201
# [934]	validation-logloss:0.67201
# [935]	validation-logloss:0.67196
# [936]	validation-logloss:0.67196
# [937]	validation-logloss:0.67196
# [938]	validation-logloss:0.67193
# [939]	validation-logloss:0.67193
# [940]	validation-logloss:0.67187
# [941]	validation-logloss:0.67187
# [942]	validation-logloss:0.67187
# [943]	validation-logloss:0.67181
# [944]	validation-logloss:0.67181
# [945]	validation-logloss:0.67176
# [946]	validation-logloss:0.67172
# [947]	validation-logloss:0.67172
# [948]	validation-logloss:0.67172
# [949]	validation-logloss:0.67167
# [950]	validation-logloss:0.67161
# [951]	validation-logloss:0.67161
# [952]	validation-logloss:0.67156
# [953]	validation-logloss:0.67156
# [954]	validation-logloss:0.67151
# [955]	validation-logloss:0.67151
# [956]	validation-logloss:0.67151
# [957]	validation-logloss:0.67151
# [958]	validation-logloss:0.67151
# [959]	validation-logloss:0.67147
# [960]	validation-logloss:0.67147
# [961]	validation-logloss:0.67147
# [962]	validation-logloss:0.67142
# [963]	validation-logloss:0.67139
# [964]	validation-logloss:0.67136
# [965]	validation-logloss:0.67132
# [966]	validation-logloss:0.67132
# [967]	validation-logloss:0.67129
# [968]	validation-logloss:0.67124
# [969]	validation-logloss:0.67118
# [970]	validation-logloss:0.67115
# [971]	validation-logloss:0.67115
# [972]	validation-logloss:0.67109
# [973]	validation-logloss:0.67106
# [974]	validation-logloss:0.67102
# [975]	validation-logloss:0.67102
# [976]	validation-logloss:0.67102
# [977]	validation-logloss:0.67102
# [978]	validation-logloss:0.67102
# [979]	validation-logloss:0.67098
# [980]	validation-logloss:0.67098
# [981]	validation-logloss:0.67092
# [982]	validation-logloss:0.67086
# [983]	validation-logloss:0.67081
# [984]	validation-logloss:0.67081
# [985]	validation-logloss:0.67081
# [986]	validation-logloss:0.67081
# [987]	validation-logloss:0.67077
# [988]	validation-logloss:0.67077
# [989]	validation-logloss:0.67077
# [990]	validation-logloss:0.67077
# [991]	validation-logloss:0.67077
# [992]	validation-logloss:0.67077
# [993]	validation-logloss:0.67074
# [994]	validation-logloss:0.67068
# [995]	validation-logloss:0.67068
# [996]	validation-logloss:0.67068
# [997]	validation-logloss:0.67063
# [998]	validation-logloss:0.67060
# [999]	validation-logloss:0.67060
# [1000]	validation-logloss:0.67060
# [1001]	validation-logloss:0.67059
# [1002]	validation-logloss:0.67059
# [1003]	validation-logloss:0.67054
# [1004]	validation-logloss:0.67048
# [1005]	validation-logloss:0.67048
# [1006]	validation-logloss:0.67045
# [1007]	validation-logloss:0.67040
# [1008]	validation-logloss:0.67036
# [1009]	validation-logloss:0.67036
# [1010]	validation-logloss:0.67031
# [1011]	validation-logloss:0.67025
# [1012]	validation-logloss:0.67025
# [1013]	validation-logloss:0.67025
# [1014]	validation-logloss:0.67025
# [1015]	validation-logloss:0.67020
# [1016]	validation-logloss:0.67015
# [1017]	validation-logloss:0.67015
# [1018]	validation-logloss:0.67015
# [1019]	validation-logloss:0.67012
# [1020]	validation-logloss:0.67012
# [1021]	validation-logloss:0.67012
# [1022]	validation-logloss:0.67012
# [1023]	validation-logloss:0.67007
# [1024]	validation-logloss:0.67004
# [1025]	validation-logloss:0.66999
# [1026]	validation-logloss:0.66999
# [1027]	validation-logloss:0.66995
# [1028]	validation-logloss:0.66995
# [1029]	validation-logloss:0.66990
# [1030]	validation-logloss:0.66987
# [1031]	validation-logloss:0.66987
# [1032]	validation-logloss:0.66981
# [1033]	validation-logloss:0.66981
# [1034]	validation-logloss:0.66981
# [1035]	validation-logloss:0.66978
# [1036]	validation-logloss:0.66973
# [1037]	validation-logloss:0.66969
# [1038]	validation-logloss:0.66969
# [1039]	validation-logloss:0.66969
# [1040]	validation-logloss:0.66969
# [1041]	validation-logloss:0.66963
# [1042]	validation-logloss:0.66957
# [1043]	validation-logloss:0.66957
# [1044]	validation-logloss:0.66952
# [1045]	validation-logloss:0.66952
# [1046]	validation-logloss:0.66952
# [1047]	validation-logloss:0.66952
# [1048]	validation-logloss:0.66952
# [1049]	validation-logloss:0.66947
# [1050]	validation-logloss:0.66947
# [1051]	validation-logloss:0.66947
# [1052]	validation-logloss:0.66947
# [1053]	validation-logloss:0.66944
# [1054]	validation-logloss:0.66941
# [1055]	validation-logloss:0.66941
# [1056]	validation-logloss:0.66941
# [1057]	validation-logloss:0.66937
# [1058]	validation-logloss:0.66937
# [1059]	validation-logloss:0.66933
# [1060]	validation-logloss:0.66933
# [1061]	validation-logloss:0.66930
# [1062]	validation-logloss:0.66930
# [1063]	validation-logloss:0.66929
# [1064]	validation-logloss:0.66929
# [1065]	validation-logloss:0.66929
# [1066]	validation-logloss:0.66924
# [1067]	validation-logloss:0.66918
# [1068]	validation-logloss:0.66913
# [1069]	validation-logloss:0.66913
# [1070]	validation-logloss:0.66913
# [1071]	validation-logloss:0.66907
# [1072]	validation-logloss:0.66907
# [1073]	validation-logloss:0.66907
# [1074]	validation-logloss:0.66901
# [1075]	validation-logloss:0.66897
# [1076]	validation-logloss:0.66894
# [1077]	validation-logloss:0.66894
# [1078]	validation-logloss:0.66890
# [1079]	validation-logloss:0.66890
# [1080]	validation-logloss:0.66890
# [1081]	validation-logloss:0.66890
# [1082]	validation-logloss:0.66890
# [1083]	validation-logloss:0.66890
# [1084]	validation-logloss:0.66885
# [1085]	validation-logloss:0.66885
# [1086]	validation-logloss:0.66885
# [1087]	validation-logloss:0.66880
# [1088]	validation-logloss:0.66874
# [1089]	validation-logloss:0.66874
# [1090]	validation-logloss:0.66874
# [1091]	validation-logloss:0.66874
# [1092]	validation-logloss:0.66874
# [1093]	validation-logloss:0.66874
# [1094]	validation-logloss:0.66871
# [1095]	validation-logloss:0.66868
# [1096]	validation-logloss:0.66868
# [1097]	validation-logloss:0.66865
# [1098]	validation-logloss:0.66861
# [1099]	validation-logloss:0.66861
# [1100]	validation-logloss:0.66861
# [1101]	validation-logloss:0.66861
# [1102]	validation-logloss:0.66856
# [1103]	validation-logloss:0.66851
# [1104]	validation-logloss:0.66851
# [1105]	validation-logloss:0.66851
# [1106]	validation-logloss:0.66846
# [1107]	validation-logloss:0.66840
# [1108]	validation-logloss:0.66837
# [1109]	validation-logloss:0.66834
# [1110]	validation-logloss:0.66834
# [1111]	validation-logloss:0.66830
# [1112]	validation-logloss:0.66825
# [1113]	validation-logloss:0.66819
# [1114]	validation-logloss:0.66816
# [1115]	validation-logloss:0.66813
# [1116]	validation-logloss:0.66808
# [1117]	validation-logloss:0.66803
# [1118]	validation-logloss:0.66803
# [1119]	validation-logloss:0.66803
# [1120]	validation-logloss:0.66803
# [1121]	validation-logloss:0.66803
# [1122]	validation-logloss:0.66803
# [1123]	validation-logloss:0.66802
# [1124]	validation-logloss:0.66802
# [1125]	validation-logloss:0.66802
# [1126]	validation-logloss:0.66802
# [1127]	validation-logloss:0.66802
# [1128]	validation-logloss:0.66797
# [1129]	validation-logloss:0.66797
# [1130]	validation-logloss:0.66797
# [1131]	validation-logloss:0.66797
# [1132]	validation-logloss:0.66797
# [1133]	validation-logloss:0.66791
# [1134]	validation-logloss:0.66787
# [1135]	validation-logloss:0.66787
# [1136]	validation-logloss:0.66782
# [1137]	validation-logloss:0.66777
# [1138]	validation-logloss:0.66774
# [1139]	validation-logloss:0.66769
# [1140]	validation-logloss:0.66769
# [1141]	validation-logloss:0.66769
# [1142]	validation-logloss:0.66764
# [1143]	validation-logloss:0.66764
# [1144]	validation-logloss:0.66761
# [1145]	validation-logloss:0.66761
# [1146]	validation-logloss:0.66757
# [1147]	validation-logloss:0.66753
# [1148]	validation-logloss:0.66753
# [1149]	validation-logloss:0.66748
# [1150]	validation-logloss:0.66743
# [1151]	validation-logloss:0.66739
# [1152]	validation-logloss:0.66733
# [1153]	validation-logloss:0.66733
# [1154]	validation-logloss:0.66733
# [1155]	validation-logloss:0.66733
# [1156]	validation-logloss:0.66733
# [1157]	validation-logloss:0.66733
# [1158]	validation-logloss:0.66733
# [1159]	validation-logloss:0.66730
# [1160]	validation-logloss:0.66730
# [1161]	validation-logloss:0.66727
# [1162]	validation-logloss:0.66724
# [1163]	validation-logloss:0.66720
# [1164]	validation-logloss:0.66717
# [1165]	validation-logloss:0.66717
# [1166]	validation-logloss:0.66714
# [1167]	validation-logloss:0.66709
# [1168]	validation-logloss:0.66709
# [1169]	validation-logloss:0.66703
# [1170]	validation-logloss:0.66697
# [1171]	validation-logloss:0.66694
# [1172]	validation-logloss:0.66690
# [1173]	validation-logloss:0.66690
# [1174]	validation-logloss:0.66686
# [1175]	validation-logloss:0.66683
# [1176]	validation-logloss:0.66680
# [1177]	validation-logloss:0.66680
# [1178]	validation-logloss:0.66675
# [1179]	validation-logloss:0.66671
# [1180]	validation-logloss:0.66671
# [1181]	validation-logloss:0.66668
# [1182]	validation-logloss:0.66662
# [1183]	validation-logloss:0.66659
# [1184]	validation-logloss:0.66654
# [1185]	validation-logloss:0.66654
# [1186]	validation-logloss:0.66651
# [1187]	validation-logloss:0.66648
# [1188]	validation-logloss:0.66645
# [1189]	validation-logloss:0.66642
# [1190]	validation-logloss:0.66642
# [1191]	validation-logloss:0.66639
# [1192]	validation-logloss:0.66633
# [1193]	validation-logloss:0.66633
# [1194]	validation-logloss:0.66630
# [1195]	validation-logloss:0.66630
# [1196]	validation-logloss:0.66624
# [1197]	validation-logloss:0.66624
# [1198]	validation-logloss:0.66621
# [1199]	validation-logloss:0.66621
# [1200]	validation-logloss:0.66621
# [1201]	validation-logloss:0.66617
# [1202]	validation-logloss:0.66617
# [1203]	validation-logloss:0.66617
# [1204]	validation-logloss:0.66617
# [1205]	validation-logloss:0.66617
# [1206]	validation-logloss:0.66617
# [1207]	validation-logloss:0.66617
# [1208]	validation-logloss:0.66612
# [1209]	validation-logloss:0.66609
# [1210]	validation-logloss:0.66609
# [1211]	validation-logloss:0.66609
# [1212]	validation-logloss:0.66609
# [1213]	validation-logloss:0.66604
# [1214]	validation-logloss:0.66604
# [1215]	validation-logloss:0.66604
# [1216]	validation-logloss:0.66604
# [1217]	validation-logloss:0.66604
# [1218]	validation-logloss:0.66604
# [1219]	validation-logloss:0.66604
# [1220]	validation-logloss:0.66600
# [1221]	validation-logloss:0.66600
# [1222]	validation-logloss:0.66600
# [1223]	validation-logloss:0.66595
# [1224]	validation-logloss:0.66589
# [1225]	validation-logloss:0.66589
# [1226]	validation-logloss:0.66589
# [1227]	validation-logloss:0.66584
# [1228]	validation-logloss:0.66584
# [1229]	validation-logloss:0.66584
# [1230]	validation-logloss:0.66584
# [1231]	validation-logloss:0.66581
# [1232]	validation-logloss:0.66578
# [1233]	validation-logloss:0.66578
# [1234]	validation-logloss:0.66575
# [1235]	validation-logloss:0.66570
# [1236]	validation-logloss:0.66570
# [1237]	validation-logloss:0.66570
# [1238]	validation-logloss:0.66570
# [1239]	validation-logloss:0.66570
# [1240]	validation-logloss:0.66565
# [1241]	validation-logloss:0.66560
# [1242]	validation-logloss:0.66554
# [1243]	validation-logloss:0.66549
# [1244]	validation-logloss:0.66544
# [1245]	validation-logloss:0.66539
# [1246]	validation-logloss:0.66534
# [1247]	validation-logloss:0.66528
# [1248]	validation-logloss:0.66528
# [1249]	validation-logloss:0.66528
# [1250]	validation-logloss:0.66528
# [1251]	validation-logloss:0.66528
# [1252]	validation-logloss:0.66528
# [1253]	validation-logloss:0.66525
# [1254]	validation-logloss:0.66522
# [1255]	validation-logloss:0.66522
# [1256]	validation-logloss:0.66522
# [1257]	validation-logloss:0.66517
# [1258]	validation-logloss:0.66517
# [1259]	validation-logloss:0.66517
# [1260]	validation-logloss:0.66512
# [1261]	validation-logloss:0.66512
# [1262]	validation-logloss:0.66512
# [1263]	validation-logloss:0.66512
# [1264]	validation-logloss:0.66506
# [1265]	validation-logloss:0.66501
# [1266]	validation-logloss:0.66501
# [1267]	validation-logloss:0.66498
# [1268]	validation-logloss:0.66498
# [1269]	validation-logloss:0.66493
# [1270]	validation-logloss:0.66493
# [1271]	validation-logloss:0.66490
# [1272]	validation-logloss:0.66485
# [1273]	validation-logloss:0.66485
# [1274]	validation-logloss:0.66482
# [1275]	validation-logloss:0.66477
# [1276]	validation-logloss:0.66473
# [1277]	validation-logloss:0.66467
# [1278]	validation-logloss:0.66463
# [1279]	validation-logloss:0.66457
# [1280]	validation-logloss:0.66451
# [1281]	validation-logloss:0.66451
# [1282]	validation-logloss:0.66451
# [1283]	validation-logloss:0.66451
# [1284]	validation-logloss:0.66451
# [1285]	validation-logloss:0.66446
# [1286]	validation-logloss:0.66446
# [1287]	validation-logloss:0.66441
# [1288]	validation-logloss:0.66436
# [1289]	validation-logloss:0.66431
# [1290]	validation-logloss:0.66431
# [1291]	validation-logloss:0.66428
# [1292]	validation-logloss:0.66423
# [1293]	validation-logloss:0.66418
# [1294]	validation-logloss:0.66415
# [1295]	validation-logloss:0.66415
# [1296]	validation-logloss:0.66409
# [1297]	validation-logloss:0.66409
# [1298]	validation-logloss:0.66409
# [1299]	validation-logloss:0.66409
# [1300]	validation-logloss:0.66404
# [1301]	validation-logloss:0.66399
# [1302]	validation-logloss:0.66396
# [1303]	validation-logloss:0.66396
# [1304]	validation-logloss:0.66396
# [1305]	validation-logloss:0.66390
# [1306]	validation-logloss:0.66390
# [1307]	validation-logloss:0.66387
# [1308]	validation-logloss:0.66384
# [1309]	validation-logloss:0.66379
# [1310]	validation-logloss:0.66379
# [1311]	validation-logloss:0.66375
# [1312]	validation-logloss:0.66371
# [1313]	validation-logloss:0.66371
# [1314]	validation-logloss:0.66371
# [1315]	validation-logloss:0.66371
# [1316]	validation-logloss:0.66371
# [1317]	validation-logloss:0.66371
# [1318]	validation-logloss:0.66371
# [1319]	validation-logloss:0.66371
# [1320]	validation-logloss:0.66371
# [1321]	validation-logloss:0.66368
# [1322]	validation-logloss:0.66363
# [1323]	validation-logloss:0.66363
# [1324]	validation-logloss:0.66363
# [1325]	validation-logloss:0.66357
# [1326]	validation-logloss:0.66357
# [1327]	validation-logloss:0.66357
# [1328]	validation-logloss:0.66357
# [1329]	validation-logloss:0.66357
# [1330]	validation-logloss:0.66357
# [1331]	validation-logloss:0.66354
# [1332]	validation-logloss:0.66354
# [1333]	validation-logloss:0.66354
# [1334]	validation-logloss:0.66350
# [1335]	validation-logloss:0.66350
# [1336]	validation-logloss:0.66347
# [1337]	validation-logloss:0.66347
# [1338]	validation-logloss:0.66341
# [1339]	validation-logloss:0.66341
# [1340]	validation-logloss:0.66341
# [1341]	validation-logloss:0.66341
# [1342]	validation-logloss:0.66341
# [1343]	validation-logloss:0.66341
# [1344]	validation-logloss:0.66338
# [1345]	validation-logloss:0.66335
# [1346]	validation-logloss:0.66335
# [1347]	validation-logloss:0.66335
# [1348]	validation-logloss:0.66335
# [1349]	validation-logloss:0.66332
# [1350]	validation-logloss:0.66332
# [1351]	validation-logloss:0.66332
# [1352]	validation-logloss:0.66326
# [1353]	validation-logloss:0.66326
# [1354]	validation-logloss:0.66326
# [1355]	validation-logloss:0.66326
# [1356]	validation-logloss:0.66326
# [1357]	validation-logloss:0.66326
# [1358]	validation-logloss:0.66320
# [1359]	validation-logloss:0.66320
# [1360]	validation-logloss:0.66320
# [1361]	validation-logloss:0.66316
# [1362]	validation-logloss:0.66316
# [1363]	validation-logloss:0.66316
# [1364]	validation-logloss:0.66316
# [1365]	validation-logloss:0.66310
# [1366]	validation-logloss:0.66310
# [1367]	validation-logloss:0.66305
# [1368]	validation-logloss:0.66300
# [1369]	validation-logloss:0.66296
# [1370]	validation-logloss:0.66296
# [1371]	validation-logloss:0.66290
# [1372]	validation-logloss:0.66287
# [1373]	validation-logloss:0.66287
# [1374]	validation-logloss:0.66287
# [1375]	validation-logloss:0.66281
# [1376]	validation-logloss:0.66281
# [1377]	validation-logloss:0.66281
# [1378]	validation-logloss:0.66277
# [1379]	validation-logloss:0.66277
# [1380]	validation-logloss:0.66271
# [1381]	validation-logloss:0.66271
# [1382]	validation-logloss:0.66271
# [1383]	validation-logloss:0.66266
# [1384]	validation-logloss:0.66266
# [1385]	validation-logloss:0.66266
# [1386]	validation-logloss:0.66266
# [1387]	validation-logloss:0.66263
# [1388]	validation-logloss:0.66259
# [1389]	validation-logloss:0.66259
# [1390]	validation-logloss:0.66256
# [1391]	validation-logloss:0.66253
# [1392]	validation-logloss:0.66250
# [1393]	validation-logloss:0.66247
# [1394]	validation-logloss:0.66247
# [1395]	validation-logloss:0.66247
# [1396]	validation-logloss:0.66247
# [1397]	validation-logloss:0.66242
# [1398]	validation-logloss:0.66237
# [1399]	validation-logloss:0.66237
# [1400]	validation-logloss:0.66232
# [1401]	validation-logloss:0.66232
# [1402]	validation-logloss:0.66232
# [1403]	validation-logloss:0.66227
# [1404]	validation-logloss:0.66227
# [1405]	validation-logloss:0.66222
# [1406]	validation-logloss:0.66222
# [1407]	validation-logloss:0.66219
# [1408]	validation-logloss:0.66213
# [1409]	validation-logloss:0.66213
# [1410]	validation-logloss:0.66210
# [1411]	validation-logloss:0.66207
# [1412]	validation-logloss:0.66202
# [1413]	validation-logloss:0.66198
# [1414]	validation-logloss:0.66193
# [1415]	validation-logloss:0.66193
# [1416]	validation-logloss:0.66190
# [1417]	validation-logloss:0.66185
# [1418]	validation-logloss:0.66185
# [1419]	validation-logloss:0.66185
# [1420]	validation-logloss:0.66185
# [1421]	validation-logloss:0.66181
# [1422]	validation-logloss:0.66181
# [1423]	validation-logloss:0.66175
# [1424]	validation-logloss:0.66175
# [1425]	validation-logloss:0.66175
# [1426]	validation-logloss:0.66175
# [1427]	validation-logloss:0.66171
# [1428]	validation-logloss:0.66171
# [1429]	validation-logloss:0.66171
# [1430]	validation-logloss:0.66166
# [1431]	validation-logloss:0.66162
# [1432]	validation-logloss:0.66162
# [1433]	validation-logloss:0.66156
# [1434]	validation-logloss:0.66152
# [1435]	validation-logloss:0.66146
# [1436]	validation-logloss:0.66146
# [1437]	validation-logloss:0.66141
# [1438]	validation-logloss:0.66138
# [1439]	validation-logloss:0.66138
# [1440]	validation-logloss:0.66138
# [1441]	validation-logloss:0.66138
# [1442]	validation-logloss:0.66135
# [1443]	validation-logloss:0.66130
# [1444]	validation-logloss:0.66130
# [1445]	validation-logloss:0.66130
# [1446]	validation-logloss:0.66125
# [1447]	validation-logloss:0.66125
# [1448]	validation-logloss:0.66125
# [1449]	validation-logloss:0.66125
# [1450]	validation-logloss:0.66125
# [1451]	validation-logloss:0.66120
# [1452]	validation-logloss:0.66114
# [1453]	validation-logloss:0.66114
# [1454]	validation-logloss:0.66108
# [1455]	validation-logloss:0.66105
# [1456]	validation-logloss:0.66101
# [1457]	validation-logloss:0.66098
# [1458]	validation-logloss:0.66095
# [1459]	validation-logloss:0.66092
# [1460]	validation-logloss:0.66092
# [1461]	validation-logloss:0.66086
# [1462]	validation-logloss:0.66081
# [1463]	validation-logloss:0.66081
# [1464]	validation-logloss:0.66075
# [1465]	validation-logloss:0.66075
# [1466]	validation-logloss:0.66072
# [1467]	validation-logloss:0.66072
# [1468]	validation-logloss:0.66072
# [1469]	validation-logloss:0.66067
# [1470]	validation-logloss:0.66067
# [1471]	validation-logloss:0.66064
# [1472]	validation-logloss:0.66064
# [1473]	validation-logloss:0.66064
# [1474]	validation-logloss:0.66061
# [1475]	validation-logloss:0.66061
# [1476]	validation-logloss:0.66061
# [1477]	validation-logloss:0.66055
# [1478]	validation-logloss:0.66051
# [1479]	validation-logloss:0.66051
# [1480]	validation-logloss:0.66048
# [1481]	validation-logloss:0.66042
# [1482]	validation-logloss:0.66038
# [1483]	validation-logloss:0.66038
# [1484]	validation-logloss:0.66035
# [1485]	validation-logloss:0.66035
# [1486]	validation-logloss:0.66029
# [1487]	validation-logloss:0.66025
# [1488]	validation-logloss:0.66022
# [1489]	validation-logloss:0.66022
# [1490]	validation-logloss:0.66022
# [1491]	validation-logloss:0.66022
# [1492]	validation-logloss:0.66022
# [1493]	validation-logloss:0.66022
# [1494]	validation-logloss:0.66017
# [1495]	validation-logloss:0.66017
# [1496]	validation-logloss:0.66014
# [1497]	validation-logloss:0.66014
# [1498]	validation-logloss:0.66009
# [1499]	validation-logloss:0.66009
# Validation Accuracy: 0.8928199791883454
# Validation ROC-AUC: 0.9516076688242509
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      1134
#            1       0.83      0.93      0.88       788
#
#     accuracy                           0.89      1922
#    macro avg       0.89      0.90      0.89      1922
# weighted avg       0.90      0.89      0.89      1922

# %%
y_test = y_test.astype(int)

# %%
dtest = xgb.DMatrix(X_test, label=y_test)
y_test_pred = bst.predict(dtest)
y_test_pred_binary = (y_test_pred > 0.5).astype(int)

# %%
print(y_test.dtype) 
print(y_test_pred_binary.dtype)
# Out:
# int64
# int64

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

accuracy = accuracy_score(y_test, y_test_pred_binary)

roc_auc = roc_auc_score(y_test, y_test_pred)

report = classification_report(y_test, y_test_pred_binary)

print(f"Test Accuracy: {accuracy}")
print(f"Test ROC-AUC: {roc_auc}")
print("Classification Report:")
print(report)
# Out:
# Test Accuracy: 0.894901144640999
# Test ROC-AUC: 0.9518243302881857
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91      1092
#            1       0.86      0.90      0.88       830
#
#     accuracy                           0.89      1922
#    macro avg       0.89      0.90      0.89      1922
# weighted avg       0.90      0.89      0.90      1922

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

numeric_data = X.select_dtypes(include=['number'])

correlation_matrix = numeric_data.corr()

plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,          
    fmt=".2f",           
    cmap="coolwarm",     
    cbar=True,           
    square=True          
)

plt.title("Correlation Matrix", fontsize=16)

plt.tight_layout()
plt.show()

# %%
new_test_file_path = '/Users/ashnaarora/Downloads/huggingface_with_perplexity.csv'
new_test_df = pd.read_csv(new_test_file_path)

print(new_test_df.head())
print(new_test_df.columns)
# Out:
#                                                 text  generated  word_count  \
# 0  With this project, participants can also learn...          1          81
# 1  Longer school days would give them less time t...          1         256
# 2  This could include having to independently pay...          1         290
# 3  Some poeple think the first impressions they c...          0         256
# 4  Also i think that the principal should decide ...          0         118
#
#    vocabulary_richness  gunning_fog  smog_index  polarity  subjectivity  \
# 0             0.728395        12.07        11.2  0.156944      0.315873
# 1             0.531250        11.65        11.7  0.073198      0.390412
# 2             0.593103        12.69        13.7  0.103705      0.519151
# 3             0.285156         6.34        11.0 -0.027778      0.543210
# 4             0.550847         8.12        10.6  0.155952      0.726190
#
#    noun_count  verb_count  adverb_count  noun_density  verb_density  \
# 0          28          11             3      0.321839      0.126437
# 1          63          42            19      0.226619      0.151079
# 2          69          53            18      0.213622      0.164087
# 3          42          60            13      0.150000      0.214286
# 4          33          22             1      0.253846      0.169231
#
#    adjective_density  adverb_density  perplexity
# 0           0.114943        0.034483   26.170715
# 1           0.111511        0.068345   17.081923
# 2           0.099071        0.055728   13.664727
# 3           0.142857        0.046429   16.209841
# 4           0.069231        0.007692   33.507610
# Index(['text', 'generated', 'word_count', 'vocabulary_richness', 'gunning_fog',
#        'smog_index', 'polarity', 'subjectivity', 'noun_count', 'verb_count',
#        'adverb_count', 'noun_density', 'verb_density', 'adjective_density',
#        'adverb_density', 'perplexity'],
#       dtype='object')

# %%
new_test_df.columns
# Out:
# Index(['text', 'generated', 'word_count', 'vocabulary_richness', 'gunning_fog',
#        'smog_index', 'polarity', 'subjectivity', 'noun_count', 'verb_count',
#        'adverb_count', 'noun_density', 'verb_density', 'adjective_density',
#        'adverb_density', 'perplexity'],
#       dtype='object')

# %%
readability_metrics = ['gunning_fog', 'smog_index', 'perplexity']
new_test_df[readability_metrics] = scaler.transform(new_test_df[readability_metrics])

columns_to_drop1 = [
    'word_count', 
    'noun_count', 'verb_count', 'adverb_count', 'text', 'vocabulary_richness', 
        'polarity', 'subjectivity', 'noun_count', 'verb_count',
       'adverb_count', 'noun_density', 'verb_density', 'adjective_density',
       'adverb_density'
]
new_test_df = new_test_df.drop(columns=columns_to_drop1, axis=1)

# %%
y_new_test = new_test_df['generated'].astype(int)
X_new_test = new_test_df.drop(columns=['generated'])

# %%
dnew_test = xgb.DMatrix(X_new_test)

# %%
new_test_pred = bst.predict(dnew_test)
new_test_pred_binary = (new_test_pred > 0.5).astype(int)

accuracy = accuracy_score(y_new_test, new_test_pred_binary)
roc_auc = roc_auc_score(y_new_test, new_test_pred)
classification_report_output = classification_report(y_new_test, new_test_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"ROC-AUC: {roc_auc}")
print("Classification Report:")
print(classification_report_output)
# Out:
# Accuracy: 0.8141333333333334
# ROC-AUC: 0.9018715644444444
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      7500
#            1       0.83      0.79      0.81      7500
#
#     accuracy                           0.81     15000
#    macro avg       0.81      0.81      0.81     15000
# weighted avg       0.81      0.81      0.81     15000

# %%
from xgboost import plot_importance
plot_importance(bst)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr_new_test, tpr_new_test, _ = roc_curve(y_new_test, new_test_pred)
roc_auc_new_test = auc(fpr_new_test, tpr_new_test)

plt.figure(figsize=(8, 6))

plt.plot(fpr_new_test, tpr_new_test, color='purple', label=f'New Test ROC curve (AUC = {roc_auc_new_test:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Chance')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for New Test Dataset')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()
