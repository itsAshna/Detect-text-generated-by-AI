# %% [markdown]
# This Notebook contains the code to generate responses from Cohere LLM, sample the HuggingFace dataset and calculate AI Ratio and Perplexity

# %%
import pandas as pd

# %%
df = pd.read_csv("train_essays.csv")
promtps = pd.read_csv("train_prompts.csv")

# %%
filtered_human_texts = df[df['generated'] == 0]
sample_data = filtered_human_texts.sample(n=1000, random_state=43)

# %% [markdown]
# Storing the reference source data to be used in the prompts while generating new data

# %%
source_0 = promtps.iloc[0]['source_text']

# %%
prompts = [
    "Write a persuasive essay explaining the benefits of reducing car usage for both individuals and society. Base your essay on evidence and information found in the passage set.",
    "Compose an informative essay to highlight the environmental, economic, and social advantages of limiting car usage. Use information from the provided passages to support your points.",
    "Draft an essay to educate readers about the importance of decreasing car dependency. Incorporate evidence from the passage set, ensuring a balanced use of multiple sources.",
    "Write an essay to discuss how reducing car usage can improve urban living conditions. Use data and insights from the passage set to back your claims.",
    "Create an analytical essay on the reasons why limiting car use is beneficial for the environment and public health. Use the passage set to gather evidence and structure your essay with clear arguments.",
    "Develop an essay explaining the role of reduced car usage in combating climate change and improving air quality. Rely on evidence from the passage set.",
    "Write an essay to explain how decreasing car reliance can lead to better urban planning and increased efficiency. Use multiple sources from the passage set to provide evidence.",
    "Construct an essay that examines the economic advantages of reducing car usage, such as cost savings and increased public transportation investment. Base your response on evidence from the passage set.",
    "Write an essay to explain how limiting car usage contributes to sustainable development and resource conservation. Use the passage set to gather evidence.",
    "Create an essay discussing how reducing car usage can help alleviate traffic congestion and improve public health. Support your points with information from the passage set.",
    "Compose an essay explaining the ways limiting car usage can benefit local economies and create more sustainable communities. Rely on information from the provided passages.",
    "Write an essay analyzing how reducing car dependency aligns with global efforts to combat climate change. Use the passage set to provide supporting evidence.",
    "Develop an essay to discuss the challenges and solutions related to limiting car usage, supported by evidence from the passage set.",
    "Construct an essay that highlights the advantages of alternative transportation methods when car usage is limited. Use evidence from the passage set to build your case.",
    "Write an essay exploring the connection between reduced car use and improved quality of life in urban areas. Use multiple sources from the passage set to support your points.",
    "Compose an essay explaining the significance of reducing car usage for urban infrastructure and community development. Use multiple sources from the passage set.",
    "Create an essay describing the potential health benefits of reducing car usage, such as lower pollution exposure and increased physical activity. Base your essay on ideas and information from the passage set.",
    "Develop an essay to explain how limiting car usage contributes to sustainable cities and addresses traffic congestion. Use information from the passage set.",
    "Write an essay describing the benefits of reducing car dependency for future generations, emphasizing long-term advantages. Use evidence from the provided passages.",
    "Compose an essay to explain the social and environmental impacts of reducing car usage, using multiple sources from the passage set."
]

# %%
temperatures = [0.8]

# %%
import csv
def save_responses_to_csv(responses, filename="generated_responses.csv"):
    header = [ "text", "generated"]
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(header)
        for i, response in enumerate(responses, 1):
            writer.writerow([response, 1])

# %% [markdown]
# # Cohere

# %%
# !pip install cohere
import cohere
# Out:
# Requirement already satisfied: cohere in /usr/local/lib/python3.10/dist-packages (5.11.4)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/lib/python3.10/dist-packages (from cohere) (1.9.7)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.27.2)
# Requirement already satisfied: httpx-sse==0.4.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.9.0)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.9.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.23.4)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.20.3)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.0.20241016)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (4.12.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.2.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers<1,>=0.15->cohere) (0.26.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.66.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.2.2)

# %%
def generate_responses_cohere(prompts, source, temperatures, api_key, num_responses=100):
    responses = []
    num_prompts = len(prompts)
    num_temps = len(temperatures)
    co = cohere.Client(api_key)
    responses_per_combination = 5

    for prompt in prompts:
        for temp in temperatures:
            for _ in range(responses_per_combination):
                formatted_prompt = f"{prompt} \n Use the Source text: {source}"
                response = co.generate(
                    model='command',
                    prompt=formatted_prompt,
                    max_tokens=150,
                    temperature=temp,
                    k=50,
                    stop_sequences=["\n"]
                )
                generated_text = response.generations[0].text.strip()
                responses.append(generated_text)
    return responses

# %%
temperatures = [0.8]
api_key = ""
responses = generate_responses_cohere(prompts, source_0, temperatures, api_key)
save_responses_to_csv(responses, "cohere-generated.csv")

# %% [markdown]
# Generating the AI ratio feature

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
import spacy
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import normalize
import re
from transformers import AutoTokenizer, AutoModel
import torch

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

file_path = 'final_huggingface_dataset.csv'
df = pd.read_csv(file_path)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
len(df)
# Out:
# 23786

# %%
'''
This function get counts of words appearing in the AI data/human data in descending order
'''
def get_counts(column):
  filtered_df = df[df['generated'] == column]
  vectorizer = CountVectorizer(stop_words='english')
  X = vectorizer.fit_transform(filtered_df['text'])
  word_counts = X.sum(axis=0).A1
  words = vectorizer.get_feature_names_out()
  word_freq = dict(zip(words, word_counts))
  sorted_word_freq = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)
  return sorted_word_freq

# %%
sorted_word_freq = get_counts('1')
sorted_word_freq1 = get_counts('0')

# %%
print(sorted_word_freq[:10])
print(sorted_word_freq1[:10])
# Out:
# [('students', 9931), ('like', 5697), ('school', 4362), ('people', 4212), ('help', 4125), ('time', 3715), ('important', 3617), ('make', 3180), ('car', 2821), ('learning', 2742)]
# [('people', 17471), ('students', 16249), ('school', 10229), ('car', 9603), ('cars', 9494), ('electoral', 8492), ('college', 7589), ('like', 7422), ('just', 7173), ('vote', 7173)]

# %%
# Calculating the ratio of word frequency in AI data/human data for each word
result = [(word, freq / freq1) if found else (word, 100) for word, freq in sorted_word_freq for word1, freq1 in sorted_word_freq1 if word == word1 or not (found := True)]

# Storing only those words that have ratio > 1.5
filtered_result = [item for item in result if item[1] >= 1.5]

#Sorting the words in descending order of their ratio
sorted_result = sorted(filtered_result, key=lambda x: x[1], reverse=True)

# %%
# Getting a list of the words
result = [i for i, score in sorted_result]

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# Check if the word is either verb, adverb, or adjective
def is_ai_word(word):
    ai_related_tags = ['VB', 'RB', 'JJ']
    doc = nlp(word)
    return doc[0].tag_ in ai_related_tags

# %%
# Filtering out the list of words based on part-of-speech
result = [i for i in result if not is_ai_word(i)]

# %%
# Calculating the AI-ratio

def calculate_ai_ratio(text, result):
    text = text.lower()
    tokens = re.findall(r'\b\w+\b', text.lower())
    ai_count = sum(1 for token in tokens if token in result)
    return ai_count / len(tokens)

# %%
# Adding the ratio to dataset and saving it
df['ai_ratio'] = df['text'].apply(lambda x: calculate_ai_ratio(x, result))
df.to_csv("new_dataset.csv", index=False)

# %% [markdown]
# Calculating the AI ratio for the test dataset

# %%
df2 = pd.read_csv('test_dataset.csv')
df2.head()
# Out:
#                                                 text  generated  word_count  \
# 0  With this project, participants can also learn...          1          81
# 1  Longer school days would give them less time t...          1         256
# 2  This could include having to independently pay...          1         290
# 3  Some poeple think the first impressions they c...          0         256
# 4  Also i think that the principal should decide ...          0         118
#
#    vocabulary_richness  gunning_fog  smog_index  polarity  subjectivity  \
# 0             0.728395        12.07        11.2  0.156944      0.315873
# 1             0.531250        11.65        11.7  0.073198      0.390412
# 2             0.593103        12.69        13.7  0.103705      0.519151
# 3             0.285156         6.34        11.0 -0.027778      0.543210
# 4             0.550847         8.12        10.6  0.155952      0.726190
#
#    noun_count  verb_count  adverb_count  noun_density  verb_density  \
# 0          28          11             3      0.321839      0.126437
# 1          63          42            19      0.226619      0.151079
# 2          69          53            18      0.213622      0.164087
# 3          42          60            13      0.150000      0.214286
# 4          33          22             1      0.253846      0.169231
#
#    adjective_density  adverb_density  perplexity
# 0           0.114943        0.034483   26.170715
# 1           0.111511        0.068345   17.081923
# 2           0.099071        0.055728   13.664727
# 3           0.142857        0.046429   16.209841
# 4           0.069231        0.007692   33.507610

# %%
df2['ai_ratio'] = df2['text'].apply(lambda x: calculate_ai_ratio(x, result))

# %%
df2.to_csv("new_dataset.csv", index=False)

# %% [markdown]
# Creating New Dataset from HuggingFace

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.9)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 16.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.3 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
from datasets import load_dataset

ds = load_dataset("dmitva/human_ai_generated_text")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# model_training_dataset.csv:   0%|          | 0.00/3.93G [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000000 [00:00<?, ? examples/s]

# %%
import pandas as pd
df = pd.DataFrame(ds['train'])

# %%
df.head()

# %%
df = df.sample(n=50000, random_state=42)

# %%
new_df = pd.DataFrame(columns=['essay_id', 'text', 'source', 'generated'])

# %%
import pandas as pd
df_transformed = pd.DataFrame({
    'essay_id': df['id'].repeat(2).values,
    'text': df[['human_text', 'ai_text']].stack().values,
    'generated': [0, 1] * len(df)
}).reset_index(drop=True)
print(df_transformed)
# Out:
#                                    essay_id  \
# 0      28354571-51ed-4e57-8b62-473b686a3346
# 1      28354571-51ed-4e57-8b62-473b686a3346
# 2      6321ea61-7264-4060-811c-cea1286aa84f
# 3      6321ea61-7264-4060-811c-cea1286aa84f
# 4      6f1591c9-6cdf-4012-93f0-dc41dbd1055d
# ...                                     ...
# 99995  029b8b13-217d-400e-9450-7058416e848f
# 99996  78d30c4b-46d2-4082-b115-3b1cd85b704e
# 99997  78d30c4b-46d2-4082-b115-3b1cd85b704e
# 99998  59bad321-a5fe-4cae-bc73-172e9166f6df
# 99999  59bad321-a5fe-4cae-bc73-172e9166f6df
#
#                                                     text  generated
# 0      Even though lots of students like to work at h...          0
# 1      \n\nUltimately, the decision as to whether stu...          1
# 2      Fresh air we're use to being home all day and ...          0
# 3      For physical activity, going to the park can b...          1
# 4      Many people believe that self-esteem comes fro...          0
# ...                                                  ...        ...
# 99995  This opened the door to several different care...          1
# 99996  School by its self puts a lot of pressure on t...          0
# 99997  \n\nFinally, educators often remain divided on...          1
# 99998  For example, I have had a hard time in school,...          0
# 99999  After a series of failed experiments, Alexande...          1
#
# [100000 rows x 3 columns]

# %%
df_transformed['source'] = 'huggingface'

# %%
df_transformed.head()
# Out:
#                                essay_id  \
# 0  e553a352-f066-4518-8431-1e59ca621e16
# 1  e553a352-f066-4518-8431-1e59ca621e16
# 2  8a2d32c2-4a67-4e5c-9f3f-8dfd42e88fca
# 3  8a2d32c2-4a67-4e5c-9f3f-8dfd42e88fca
# 4  9ef77519-ec09-4038-92a8-7f8f5fc3a1b5
#
#                                                 text  generated       source
# 0  For those reasons I think class in arts should...          0  huggingface
# 1  \n\nFrom my own experience, taking classes in ...          1  huggingface
# 2  But, they their is a negative effects on peopl...          0  huggingface
# 3  It has made our lives easier in many ways, but...          1  huggingface
# 4  You don't have to change yourself to prove a p...          0  huggingface

# %%
df_transformed.to_csv('100kdataset.csv', index=False)

# %% [markdown]
# Calculating perplexity

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name).to(device)

MODEL_MAX_LENGTH = model.config.max_position_embeddings

def calculate_chunk_perplexity(chunk, tokenizer, model):
    try:
        tokens = tokenizer.encode(chunk, return_tensors="pt", truncation=True, max_length=MODEL_MAX_LENGTH).to(device)
        if tokens.size(1) == 0:
            print(f"Empty token sequence for chunk: {chunk[:50]}...")
            return None
        with torch.no_grad():
            outputs = model(tokens, labels=tokens)
            loss = outputs.loss
            if loss is None or torch.isnan(loss):
                print(f"Loss is NaN for chunk: {chunk[:50]}...")
                return None
        return torch.exp(loss).cpu().item()
    except Exception as e:
        print(f"Error processing chunk: {chunk[:50]}... | Error: {e}")
        return None

# Function to handle long texts by splitting into chunks
def calculate_text_perplexity(text, tokenizer, model):
    tokens = tokenizer.encode(text)
    if len(tokens) <= MODEL_MAX_LENGTH:
        return calculate_chunk_perplexity(text, tokenizer, model)
    else:
        chunks = [tokens[i:i + MODEL_MAX_LENGTH] for i in range(0, len(tokens), MODEL_MAX_LENGTH)]
        chunk_texts = [tokenizer.decode(chunk, skip_special_tokens=True) for chunk in chunks]
        perplexities = []
        for chunk in chunk_texts:
            chunk_perplexity = calculate_chunk_perplexity(chunk, tokenizer, model)
            if chunk_perplexity is not None:
                perplexities.append(chunk_perplexity)
        if perplexities:
            return sum(perplexities) / len(perplexities)
        return None

# Function to process dataset in batches for NaN perplexity rows
def recalculate_na_perplexity_in_batches(dataset, batch_size=100, save_path="test_dataset.csv"):
    rows_with_na = dataset[dataset['perplexity'].isna()]
    print(f"Total rows with NaN perplexity: {len(rows_with_na)}")

    total_rows = len(rows_with_na)
    for start in range(0, total_rows, batch_size):
        end = min(start + batch_size, total_rows)
        batch_indices = rows_with_na.index[start:end]
        print(f"Processing batch {start // batch_size + 1} ({start}-{end})...")

        for idx in batch_indices:
            row = dataset.loc[idx]
            perplexity = calculate_text_perplexity(row["text"], tokenizer, model)
            dataset.at[idx, "perplexity"] = perplexity

        dataset.to_csv(save_path, index=False)
        print(f"Completed batch {start // batch_size + 1} and saved to {save_path}")

dataset = df
dataset["perplexity"] = None

# Clean text column
dataset['text'] = dataset['text'].fillna('').str.strip()
# Recalculate perplexity for NaN rows in batches
recalculate_na_perplexity_in_batches(dataset, batch_size=100, save_path="Dataset_with_new_features.csv")
# Out:
# Total rows with NaN perplexity: 23786
# Processing batch 1 (0-100)...
# Token indices sequence length is longer than the specified maximum sequence length for this model (1048 > 1024). Running this sequence through the model will result in indexing errors
# Completed batch 1 and saved to Dataset_with_new_features.csv
# Processing batch 2 (100-200)...
# Completed batch 2 and saved to Dataset_with_new_features.csv
# Processing batch 3 (200-300)...
# Completed batch 3 and saved to Dataset_with_new_features.csv
# Processing batch 4 (300-400)...
# Completed batch 4 and saved to Dataset_with_new_features.csv
# Processing batch 5 (400-500)...
# Completed batch 5 and saved to Dataset_with_new_features.csv
# Processing batch 6 (500-600)...
# Completed batch 6 and saved to Dataset_with_new_features.csv
# Processing batch 7 (600-700)...
# Completed batch 7 and saved to Dataset_with_new_features.csv
# Processing batch 8 (700-800)...
# Completed batch 8 and saved to Dataset_with_new_features.csv
# Processing batch 9 (800-900)...
# Completed batch 9 and saved to Dataset_with_new_features.csv
# Processing batch 10 (900-1000)...
# Completed batch 10 and saved to Dataset_with_new_features.csv
# Processing batch 11 (1000-1100)...
# Completed batch 11 and saved to Dataset_with_new_features.csv
# Processing batch 12 (1100-1200)...
# Completed batch 12 and saved to Dataset_with_new_features.csv
# Processing batch 13 (1200-1300)...
# Completed batch 13 and saved to Dataset_with_new_features.csv
# Processing batch 14 (1300-1400)...
# Completed batch 14 and saved to Dataset_with_new_features.csv
# Processing batch 15 (1400-1500)...
# Completed batch 15 and saved to Dataset_with_new_features.csv
# Processing batch 16 (1500-1600)...
# Completed batch 16 and saved to Dataset_with_new_features.csv
# Processing batch 17 (1600-1700)...
# Completed batch 17 and saved to Dataset_with_new_features.csv
# Processing batch 18 (1700-1800)...
# Completed batch 18 and saved to Dataset_with_new_features.csv
# Processing batch 19 (1800-1900)...
# Completed batch 19 and saved to Dataset_with_new_features.csv
# Processing batch 20 (1900-2000)...
# Completed batch 20 and saved to Dataset_with_new_features.csv
# Processing batch 21 (2000-2100)...
# Completed batch 21 and saved to Dataset_with_new_features.csv
# Processing batch 22 (2100-2200)...
# Completed batch 22 and saved to Dataset_with_new_features.csv
# Processing batch 23 (2200-2300)...
# Completed batch 23 and saved to Dataset_with_new_features.csv
# Processing batch 24 (2300-2400)...
# Completed batch 24 and saved to Dataset_with_new_features.csv
# Processing batch 25 (2400-2500)...
# Completed batch 25 and saved to Dataset_with_new_features.csv
# Processing batch 26 (2500-2600)...
# Completed batch 26 and saved to Dataset_with_new_features.csv
# Processing batch 27 (2600-2700)...
# Completed batch 27 and saved to Dataset_with_new_features.csv
# Processing batch 28 (2700-2800)...
# Completed batch 28 and saved to Dataset_with_new_features.csv
# Processing batch 29 (2800-2900)...
# Completed batch 29 and saved to Dataset_with_new_features.csv
# Processing batch 30 (2900-3000)...
# Completed batch 30 and saved to Dataset_with_new_features.csv
# Processing batch 31 (3000-3100)...
# Completed batch 31 and saved to Dataset_with_new_features.csv
# Processing batch 32 (3100-3200)...
# Completed batch 32 and saved to Dataset_with_new_features.csv
# Processing batch 33 (3200-3300)...
# Completed batch 33 and saved to Dataset_with_new_features.csv
# Processing batch 34 (3300-3400)...
# Completed batch 34 and saved to Dataset_with_new_features.csv
# Processing batch 35 (3400-3500)...
# Completed batch 35 and saved to Dataset_with_new_features.csv
# Processing batch 36 (3500-3600)...
# Completed batch 36 and saved to Dataset_with_new_features.csv
# Processing batch 37 (3600-3700)...
# Completed batch 37 and saved to Dataset_with_new_features.csv
# Processing batch 38 (3700-3800)...
# Completed batch 38 and saved to Dataset_with_new_features.csv
# Processing batch 39 (3800-3900)...
# Completed batch 39 and saved to Dataset_with_new_features.csv
# Processing batch 40 (3900-4000)...
# Completed batch 40 and saved to Dataset_with_new_features.csv
# Processing batch 41 (4000-4100)...
# Completed batch 41 and saved to Dataset_with_new_features.csv
# Processing batch 42 (4100-4200)...
# Completed batch 42 and saved to Dataset_with_new_features.csv
# Processing batch 43 (4200-4300)...
# Completed batch 43 and saved to Dataset_with_new_features.csv
# Processing batch 44 (4300-4400)...
# Completed batch 44 and saved to Dataset_with_new_features.csv
# Processing batch 45 (4400-4500)...
# Completed batch 45 and saved to Dataset_with_new_features.csv
# Processing batch 46 (4500-4600)...
# Completed batch 46 and saved to Dataset_with_new_features.csv
# Processing batch 47 (4600-4700)...
# Completed batch 47 and saved to Dataset_with_new_features.csv
# Processing batch 48 (4700-4800)...
# Completed batch 48 and saved to Dataset_with_new_features.csv
# Processing batch 49 (4800-4900)...
# Completed batch 49 and saved to Dataset_with_new_features.csv
# Processing batch 50 (4900-5000)...
# Completed batch 50 and saved to Dataset_with_new_features.csv
# Processing batch 51 (5000-5100)...
# Completed batch 51 and saved to Dataset_with_new_features.csv
# Processing batch 52 (5100-5200)...
# Completed batch 52 and saved to Dataset_with_new_features.csv
# Processing batch 53 (5200-5300)...
# Completed batch 53 and saved to Dataset_with_new_features.csv
# Processing batch 54 (5300-5400)...
# Completed batch 54 and saved to Dataset_with_new_features.csv
# Processing batch 55 (5400-5500)...
# Completed batch 55 and saved to Dataset_with_new_features.csv
# Processing batch 56 (5500-5600)...
# Completed batch 56 and saved to Dataset_with_new_features.csv
# Processing batch 57 (5600-5700)...
# Completed batch 57 and saved to Dataset_with_new_features.csv
# Processing batch 58 (5700-5800)...
# Completed batch 58 and saved to Dataset_with_new_features.csv
# Processing batch 59 (5800-5900)...
# Completed batch 59 and saved to Dataset_with_new_features.csv
# Processing batch 60 (5900-6000)...
# Completed batch 60 and saved to Dataset_with_new_features.csv
# Processing batch 61 (6000-6100)...
# Completed batch 61 and saved to Dataset_with_new_features.csv
# Processing batch 62 (6100-6200)...
# Completed batch 62 and saved to Dataset_with_new_features.csv
# Processing batch 63 (6200-6300)...
# Completed batch 63 and saved to Dataset_with_new_features.csv
# Processing batch 64 (6300-6400)...
# Completed batch 64 and saved to Dataset_with_new_features.csv
# Processing batch 65 (6400-6500)...
# Completed batch 65 and saved to Dataset_with_new_features.csv
# Processing batch 66 (6500-6600)...
# Completed batch 66 and saved to Dataset_with_new_features.csv
# Processing batch 67 (6600-6700)...
# Completed batch 67 and saved to Dataset_with_new_features.csv
# Processing batch 68 (6700-6800)...
# Completed batch 68 and saved to Dataset_with_new_features.csv
# Processing batch 69 (6800-6900)...
# Completed batch 69 and saved to Dataset_with_new_features.csv
# Processing batch 70 (6900-7000)...
# Completed batch 70 and saved to Dataset_with_new_features.csv
# Processing batch 71 (7000-7100)...
# Completed batch 71 and saved to Dataset_with_new_features.csv
# Processing batch 72 (7100-7200)...
# Completed batch 72 and saved to Dataset_with_new_features.csv
# Processing batch 73 (7200-7300)...
# Completed batch 73 and saved to Dataset_with_new_features.csv
# Processing batch 74 (7300-7400)...
# Completed batch 74 and saved to Dataset_with_new_features.csv
# Processing batch 75 (7400-7500)...
# Completed batch 75 and saved to Dataset_with_new_features.csv
# Processing batch 76 (7500-7600)...
# Completed batch 76 and saved to Dataset_with_new_features.csv
# Processing batch 77 (7600-7700)...
# Completed batch 77 and saved to Dataset_with_new_features.csv
# Processing batch 78 (7700-7800)...
# Completed batch 78 and saved to Dataset_with_new_features.csv
# Processing batch 79 (7800-7900)...
# Completed batch 79 and saved to Dataset_with_new_features.csv
# Processing batch 80 (7900-8000)...
# Completed batch 80 and saved to Dataset_with_new_features.csv
# Processing batch 81 (8000-8100)...
# Completed batch 81 and saved to Dataset_with_new_features.csv
# Processing batch 82 (8100-8200)...
# Completed batch 82 and saved to Dataset_with_new_features.csv
# Processing batch 83 (8200-8300)...
# Completed batch 83 and saved to Dataset_with_new_features.csv
# Processing batch 84 (8300-8400)...
# Completed batch 84 and saved to Dataset_with_new_features.csv
# Processing batch 85 (8400-8500)...
# Completed batch 85 and saved to Dataset_with_new_features.csv
# Processing batch 86 (8500-8600)...
# Completed batch 86 and saved to Dataset_with_new_features.csv
# Processing batch 87 (8600-8700)...
# Completed batch 87 and saved to Dataset_with_new_features.csv
# Processing batch 88 (8700-8800)...
# Completed batch 88 and saved to Dataset_with_new_features.csv
# Processing batch 89 (8800-8900)...
# Completed batch 89 and saved to Dataset_with_new_features.csv
# Processing batch 90 (8900-9000)...
# Completed batch 90 and saved to Dataset_with_new_features.csv
# Processing batch 91 (9000-9100)...
# Completed batch 91 and saved to Dataset_with_new_features.csv
# Processing batch 92 (9100-9200)...
# Completed batch 92 and saved to Dataset_with_new_features.csv
# Processing batch 93 (9200-9300)...
# Completed batch 93 and saved to Dataset_with_new_features.csv
# Processing batch 94 (9300-9400)...
# Completed batch 94 and saved to Dataset_with_new_features.csv
# Processing batch 95 (9400-9500)...
# Completed batch 95 and saved to Dataset_with_new_features.csv
# Processing batch 96 (9500-9600)...
# Completed batch 96 and saved to Dataset_with_new_features.csv
# Processing batch 97 (9600-9700)...
# Completed batch 97 and saved to Dataset_with_new_features.csv
# Processing batch 98 (9700-9800)...
# Completed batch 98 and saved to Dataset_with_new_features.csv
# Processing batch 99 (9800-9900)...
# Completed batch 99 and saved to Dataset_with_new_features.csv
# Processing batch 100 (9900-10000)...
# Completed batch 100 and saved to Dataset_with_new_features.csv
# Processing batch 101 (10000-10100)...
# Completed batch 101 and saved to Dataset_with_new_features.csv
# Processing batch 102 (10100-10200)...
# Completed batch 102 and saved to Dataset_with_new_features.csv
# Processing batch 103 (10200-10300)...
# Completed batch 103 and saved to Dataset_with_new_features.csv
# Processing batch 104 (10300-10400)...
# Completed batch 104 and saved to Dataset_with_new_features.csv
# Processing batch 105 (10400-10500)...
# Completed batch 105 and saved to Dataset_with_new_features.csv
# Processing batch 106 (10500-10600)...
# Completed batch 106 and saved to Dataset_with_new_features.csv
# Processing batch 107 (10600-10700)...
# Completed batch 107 and saved to Dataset_with_new_features.csv
# Processing batch 108 (10700-10800)...
# Completed batch 108 and saved to Dataset_with_new_features.csv
# Processing batch 109 (10800-10900)...
# Completed batch 109 and saved to Dataset_with_new_features.csv
# Processing batch 110 (10900-11000)...
# Completed batch 110 and saved to Dataset_with_new_features.csv
# Processing batch 111 (11000-11100)...
# Completed batch 111 and saved to Dataset_with_new_features.csv
# Processing batch 112 (11100-11200)...
# Completed batch 112 and saved to Dataset_with_new_features.csv
# Processing batch 113 (11200-11300)...
# Completed batch 113 and saved to Dataset_with_new_features.csv
# Processing batch 114 (11300-11400)...
# Completed batch 114 and saved to Dataset_with_new_features.csv
# Processing batch 115 (11400-11500)...
# Completed batch 115 and saved to Dataset_with_new_features.csv
# Processing batch 116 (11500-11600)...
# Completed batch 116 and saved to Dataset_with_new_features.csv
# Processing batch 117 (11600-11700)...
# Completed batch 117 and saved to Dataset_with_new_features.csv
# Processing batch 118 (11700-11800)...
# Completed batch 118 and saved to Dataset_with_new_features.csv
# Processing batch 119 (11800-11900)...
# Completed batch 119 and saved to Dataset_with_new_features.csv
# Processing batch 120 (11900-12000)...
# Completed batch 120 and saved to Dataset_with_new_features.csv
# Processing batch 121 (12000-12100)...
# Completed batch 121 and saved to Dataset_with_new_features.csv
# Processing batch 122 (12100-12200)...
# Completed batch 122 and saved to Dataset_with_new_features.csv
# Processing batch 123 (12200-12300)...
# Completed batch 123 and saved to Dataset_with_new_features.csv
# Processing batch 124 (12300-12400)...
# Completed batch 124 and saved to Dataset_with_new_features.csv
# Processing batch 125 (12400-12500)...
# Completed batch 125 and saved to Dataset_with_new_features.csv
# Processing batch 126 (12500-12600)...
# Completed batch 126 and saved to Dataset_with_new_features.csv
# Processing batch 127 (12600-12700)...
# Completed batch 127 and saved to Dataset_with_new_features.csv
# Processing batch 128 (12700-12800)...
# Completed batch 128 and saved to Dataset_with_new_features.csv
# Processing batch 129 (12800-12900)...
# Completed batch 129 and saved to Dataset_with_new_features.csv
# Processing batch 130 (12900-13000)...
# Completed batch 130 and saved to Dataset_with_new_features.csv
# Processing batch 131 (13000-13100)...
# Completed batch 131 and saved to Dataset_with_new_features.csv
# Processing batch 132 (13100-13200)...
# Completed batch 132 and saved to Dataset_with_new_features.csv
# Processing batch 133 (13200-13300)...
# Completed batch 133 and saved to Dataset_with_new_features.csv
# Processing batch 134 (13300-13400)...
# Completed batch 134 and saved to Dataset_with_new_features.csv
# Processing batch 135 (13400-13500)...
# Completed batch 135 and saved to Dataset_with_new_features.csv
# Processing batch 136 (13500-13600)...
# Completed batch 136 and saved to Dataset_with_new_features.csv
# Processing batch 137 (13600-13700)...
# Completed batch 137 and saved to Dataset_with_new_features.csv
# Processing batch 138 (13700-13800)...
# Completed batch 138 and saved to Dataset_with_new_features.csv
# Processing batch 139 (13800-13900)...
# Completed batch 139 and saved to Dataset_with_new_features.csv
# Processing batch 140 (13900-14000)...
# Completed batch 140 and saved to Dataset_with_new_features.csv
# Processing batch 141 (14000-14100)...
# Completed batch 141 and saved to Dataset_with_new_features.csv
# Processing batch 142 (14100-14200)...
# Completed batch 142 and saved to Dataset_with_new_features.csv
# Processing batch 143 (14200-14300)...
# Completed batch 143 and saved to Dataset_with_new_features.csv
# Processing batch 144 (14300-14400)...
# Completed batch 144 and saved to Dataset_with_new_features.csv
# Processing batch 145 (14400-14500)...
# Completed batch 145 and saved to Dataset_with_new_features.csv
# Processing batch 146 (14500-14600)...
# Completed batch 146 and saved to Dataset_with_new_features.csv
# Processing batch 147 (14600-14700)...
# Completed batch 147 and saved to Dataset_with_new_features.csv
# Processing batch 148 (14700-14800)...
# Completed batch 148 and saved to Dataset_with_new_features.csv
# Processing batch 149 (14800-14900)...
# Completed batch 149 and saved to Dataset_with_new_features.csv
# Processing batch 150 (14900-15000)...
# Completed batch 150 and saved to Dataset_with_new_features.csv
# Processing batch 151 (15000-15100)...
# Completed batch 151 and saved to Dataset_with_new_features.csv
# Processing batch 152 (15100-15200)...
# Completed batch 152 and saved to Dataset_with_new_features.csv
# Processing batch 153 (15200-15300)...
# Completed batch 153 and saved to Dataset_with_new_features.csv
# Processing batch 154 (15300-15400)...
# Completed batch 154 and saved to Dataset_with_new_features.csv
# Processing batch 155 (15400-15500)...
# Completed batch 155 and saved to Dataset_with_new_features.csv
# Processing batch 156 (15500-15600)...
# Completed batch 156 and saved to Dataset_with_new_features.csv
# Processing batch 157 (15600-15700)...
# Completed batch 157 and saved to Dataset_with_new_features.csv
# Processing batch 158 (15700-15800)...
# Completed batch 158 and saved to Dataset_with_new_features.csv
# Processing batch 159 (15800-15900)...
# Completed batch 159 and saved to Dataset_with_new_features.csv
# Processing batch 160 (15900-16000)...
# Completed batch 160 and saved to Dataset_with_new_features.csv
# Processing batch 161 (16000-16100)...
# Completed batch 161 and saved to Dataset_with_new_features.csv
# Processing batch 162 (16100-16200)...
# Completed batch 162 and saved to Dataset_with_new_features.csv
# Processing batch 163 (16200-16300)...
# Completed batch 163 and saved to Dataset_with_new_features.csv
# Processing batch 164 (16300-16400)...
# Completed batch 164 and saved to Dataset_with_new_features.csv
# Processing batch 165 (16400-16500)...
# Completed batch 165 and saved to Dataset_with_new_features.csv
# Processing batch 166 (16500-16600)...
# Completed batch 166 and saved to Dataset_with_new_features.csv
# Processing batch 167 (16600-16700)...
# Completed batch 167 and saved to Dataset_with_new_features.csv
# Processing batch 168 (16700-16800)...
# Completed batch 168 and saved to Dataset_with_new_features.csv
# Processing batch 169 (16800-16900)...
# Completed batch 169 and saved to Dataset_with_new_features.csv
# Processing batch 170 (16900-17000)...
# Completed batch 170 and saved to Dataset_with_new_features.csv
# Processing batch 171 (17000-17100)...
# Completed batch 171 and saved to Dataset_with_new_features.csv
# Processing batch 172 (17100-17200)...
# Completed batch 172 and saved to Dataset_with_new_features.csv
# Processing batch 173 (17200-17300)...
# Completed batch 173 and saved to Dataset_with_new_features.csv
# Processing batch 174 (17300-17400)...
# Completed batch 174 and saved to Dataset_with_new_features.csv
# Processing batch 175 (17400-17500)...
# Completed batch 175 and saved to Dataset_with_new_features.csv
# Processing batch 176 (17500-17600)...
# Completed batch 176 and saved to Dataset_with_new_features.csv
# Processing batch 177 (17600-17700)...
# Completed batch 177 and saved to Dataset_with_new_features.csv
# Processing batch 178 (17700-17800)...
# Completed batch 178 and saved to Dataset_with_new_features.csv
# Processing batch 179 (17800-17900)...
# Completed batch 179 and saved to Dataset_with_new_features.csv
# Processing batch 180 (17900-18000)...
# Completed batch 180 and saved to Dataset_with_new_features.csv
# Processing batch 181 (18000-18100)...
# Completed batch 181 and saved to Dataset_with_new_features.csv
# Processing batch 182 (18100-18200)...
# Completed batch 182 and saved to Dataset_with_new_features.csv
# Processing batch 183 (18200-18300)...
# Completed batch 183 and saved to Dataset_with_new_features.csv
# Processing batch 184 (18300-18400)...
# Completed batch 184 and saved to Dataset_with_new_features.csv
# Processing batch 185 (18400-18500)...
# Completed batch 185 and saved to Dataset_with_new_features.csv
# Processing batch 186 (18500-18600)...
# Completed batch 186 and saved to Dataset_with_new_features.csv
# Processing batch 187 (18600-18700)...
# Completed batch 187 and saved to Dataset_with_new_features.csv
# Processing batch 188 (18700-18800)...
# Completed batch 188 and saved to Dataset_with_new_features.csv
# Processing batch 189 (18800-18900)...
# Completed batch 189 and saved to Dataset_with_new_features.csv
# Processing batch 190 (18900-19000)...
# Completed batch 190 and saved to Dataset_with_new_features.csv
# Processing batch 191 (19000-19100)...
# Completed batch 191 and saved to Dataset_with_new_features.csv
# Processing batch 192 (19100-19200)...
# Completed batch 192 and saved to Dataset_with_new_features.csv
# Processing batch 193 (19200-19300)...
# Completed batch 193 and saved to Dataset_with_new_features.csv
# Processing batch 194 (19300-19400)...
# Completed batch 194 and saved to Dataset_with_new_features.csv
# Processing batch 195 (19400-19500)...
# Completed batch 195 and saved to Dataset_with_new_features.csv
# Processing batch 196 (19500-19600)...
# Completed batch 196 and saved to Dataset_with_new_features.csv
# Processing batch 197 (19600-19700)...
# Completed batch 197 and saved to Dataset_with_new_features.csv
# Processing batch 198 (19700-19800)...
# Completed batch 198 and saved to Dataset_with_new_features.csv
# Processing batch 199 (19800-19900)...
# Completed batch 199 and saved to Dataset_with_new_features.csv
# Processing batch 200 (19900-20000)...
# Completed batch 200 and saved to Dataset_with_new_features.csv
# Processing batch 201 (20000-20100)...
# Completed batch 201 and saved to Dataset_with_new_features.csv
# Processing batch 202 (20100-20200)...
# Completed batch 202 and saved to Dataset_with_new_features.csv
# Processing batch 203 (20200-20300)...
# Completed batch 203 and saved to Dataset_with_new_features.csv
# Processing batch 204 (20300-20400)...
# Completed batch 204 and saved to Dataset_with_new_features.csv
# Processing batch 205 (20400-20500)...
# Completed batch 205 and saved to Dataset_with_new_features.csv
# Processing batch 206 (20500-20600)...
# Completed batch 206 and saved to Dataset_with_new_features.csv
# Processing batch 207 (20600-20700)...
# Completed batch 207 and saved to Dataset_with_new_features.csv
# Processing batch 208 (20700-20800)...
# Completed batch 208 and saved to Dataset_with_new_features.csv
# Processing batch 209 (20800-20900)...
# Completed batch 209 and saved to Dataset_with_new_features.csv
# Processing batch 210 (20900-21000)...
# Completed batch 210 and saved to Dataset_with_new_features.csv
# Processing batch 211 (21000-21100)...
# Completed batch 211 and saved to Dataset_with_new_features.csv
# Processing batch 212 (21100-21200)...
# Completed batch 212 and saved to Dataset_with_new_features.csv
# Processing batch 213 (21200-21300)...
# Completed batch 213 and saved to Dataset_with_new_features.csv
# Processing batch 214 (21300-21400)...
# Completed batch 214 and saved to Dataset_with_new_features.csv
# Processing batch 215 (21400-21500)...
# Completed batch 215 and saved to Dataset_with_new_features.csv
# Processing batch 216 (21500-21600)...
# Completed batch 216 and saved to Dataset_with_new_features.csv
# Processing batch 217 (21600-21700)...
# Completed batch 217 and saved to Dataset_with_new_features.csv
# Processing batch 218 (21700-21800)...
# Completed batch 218 and saved to Dataset_with_new_features.csv
# Processing batch 219 (21800-21900)...
# Completed batch 219 and saved to Dataset_with_new_features.csv
# Processing batch 220 (21900-22000)...
# Completed batch 220 and saved to Dataset_with_new_features.csv
# Processing batch 221 (22000-22100)...
# Completed batch 221 and saved to Dataset_with_new_features.csv
# Processing batch 222 (22100-22200)...
# Completed batch 222 and saved to Dataset_with_new_features.csv
# Processing batch 223 (22200-22300)...
# Completed batch 223 and saved to Dataset_with_new_features.csv
# Processing batch 224 (22300-22400)...
# Completed batch 224 and saved to Dataset_with_new_features.csv
# Processing batch 225 (22400-22500)...
# Completed batch 225 and saved to Dataset_with_new_features.csv
# Processing batch 226 (22500-22600)...
# Completed batch 226 and saved to Dataset_with_new_features.csv
# Processing batch 227 (22600-22700)...
# Completed batch 227 and saved to Dataset_with_new_features.csv
# Processing batch 228 (22700-22800)...
# Completed batch 228 and saved to Dataset_with_new_features.csv
# Processing batch 229 (22800-22900)...
# Completed batch 229 and saved to Dataset_with_new_features.csv
# Processing batch 230 (22900-23000)...
# Completed batch 230 and saved to Dataset_with_new_features.csv
# Processing batch 231 (23000-23100)...
# Completed batch 231 and saved to Dataset_with_new_features.csv
# Processing batch 232 (23100-23200)...
# Completed batch 232 and saved to Dataset_with_new_features.csv
# Processing batch 233 (23200-23300)...
# Completed batch 233 and saved to Dataset_with_new_features.csv
# Processing batch 234 (23300-23400)...
# Completed batch 234 and saved to Dataset_with_new_features.csv
# Processing batch 235 (23400-23500)...
# Completed batch 235 and saved to Dataset_with_new_features.csv
# Processing batch 236 (23500-23600)...
# Completed batch 236 and saved to Dataset_with_new_features.csv
# Processing batch 237 (23600-23700)...
# Completed batch 237 and saved to Dataset_with_new_features.csv
# Processing batch 238 (23700-23786)...
# Completed batch 238 and saved to Dataset_with_new_features.csv
